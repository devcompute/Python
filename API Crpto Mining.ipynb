# %%
  
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2022-09-16T21:23:03.632Z', 'error_code': 0, 'error_message': None, 'elapsed': 32, 'credit_count': 1, 'notice': None, 'total_count': 9429}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9746, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio'], 'max_supply': 21000000, 'circulating_supply': 19152393, 'total_supply': 19152393, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2022-09-16T21:21:00.000Z', 'quote': {'USD': {'price': 19736.15435734029, 'volume_24h': 30498842916.625454, 'volume_change_24h': -17.8089, 'percent_change_1h': 0.41459937, 'percent_change_24h': -0.60514144, 'percent_change_7d': -7.11927733, 'percent_change_30d': -15.43681458, 'percent_change_60d': -8.65569885, 'percent_change_90d': 9.94592105, 'market_cap': 377994584560.44366, 'market_cap_dominance': 39.4323, 'fully_diluted_market_cap': 414459241504.15, 'tvl': None, 'last_updated': '2022-09-16T21:21:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6092, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable', 'pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem'], 'max_supply': None, 'circulating_supply': 122396005.499, 'total_supply': 122396005.499, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2022-09-16T21:21:00.000Z', 'quote': {'USD': {'price': 1436.9935341309451, 'volume_24h': 17442475989.824467, 'volume_change_24h': -35.6797, 'percent_change_1h': 0.36595639, 'percent_change_24h': -4.24501818, 'percent_change_7d': -16.35697277, 'percent_change_30d': -22.06838943, 'percent_change_60d': -2.81194384, 'percent_change_90d': 58.46893497, 'market_cap': 175882268505.51862, 'market_cap_dominance': 18.3516, 'fully_diluted_market_cap': 175882268505.52, 'tvl': None, 'last_updated': '2022-09-16T21:21:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 39784, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin'], 'max_supply': None, 'circulating_supply': 67923438459.07519, 'total_supply': 70156782826.04665, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}, 'cmc_rank ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#       id         name symbol                  slug  num_market_pairs  \
# 0      1      Bitcoin    BTC               bitcoin              9743
# 1   1027     Ethereum    ETH              ethereum              6091
# 2    825       Tether   USDT                tether             39723
# 3   3408     USD Coin   USDC              usd-coin              6198
# 4   1839          BNB    BNB                   bnb              1103
# 5   4687  Binance USD   BUSD           binance-usd              5089
# 6     52          XRP    XRP                   xrp               814
# 7   2010      Cardano    ADA               cardano               569
# 8   5426       Solana    SOL                solana               383
# 9     74     Dogecoin   DOGE              dogecoin               562
# 10  6636     Polkadot    DOT          polkadot-new               410
# 11  3890      Polygon  MATIC               polygon               484
# 12  4943          Dai    DAI  multi-collateral-dai              1340
# 13  5994    Shiba Inu   SHIB             shiba-inu               413
# 14  1958         TRON    TRX                  tron               684
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2018-10-08T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2019-09-20T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-04-10T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2019-04-28T00:00:00.000Z
# 12  2019-11-22T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [mineable, pos, smart-contracts, ethereum-ecos...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 4   [marketplace, centralized-exchange, payments, ...  2.000000e+08
# 5   [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 8   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 9   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 11  [platform, enterprise-solutions, scaling, stat...  1.000000e+10
# 12  [defi, stablecoin, asset-backed-stablecoin, et...           NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 14                  [media, payments, tron-ecosystem]           NaN
#
#     circulating_supply  total_supply  platform  cmc_rank  \
# 0         1.915127e+07  1.915127e+07       NaN         1
# 1         1.223771e+08  1.223771e+08       NaN         2
# 2         6.788344e+10  6.915678e+10       NaN         3
# 3         5.076509e+10  5.076509e+10       NaN         4
# 4         1.613373e+08  1.613373e+08       NaN         5
# 5         2.051725e+10  2.051725e+10       NaN         6
# 6         4.982602e+10  9.998930e+10       NaN         7
# 7         3.418204e+10  3.485495e+10       NaN         8
# 8         3.539800e+08  5.116169e+08       NaN         9
# 9         1.326708e+11  1.326708e+11       NaN        10
# 10        1.117140e+09  1.232564e+09       NaN        11
# 11        8.734317e+09  1.000000e+10       NaN        12
# 12        6.848745e+09  6.848745e+09       NaN        13
# 13        5.490633e+14  5.897350e+14       NaN        14
# 14        9.236559e+10  9.236562e+10       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                      9.048698e+08              6.438767e+09      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                      7.165966e+10              4.420564e+09      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2022-09-15T14:03:00.000Z     20137.218900          3.861006e+10
# 1   2022-09-15T14:03:00.000Z      1588.054046          2.504546e+10
# 2   2022-09-15T14:03:00.000Z         1.000028          6.182823e+10
# 3   2022-09-15T14:03:00.000Z         1.000074          7.122691e+09
# 4   2022-09-15T14:03:00.000Z       276.336376          1.054576e+09
# 5   2022-09-15T14:03:00.000Z         1.000271          1.048498e+10
# 6   2022-09-15T14:03:00.000Z         0.333080          1.435265e+09
# 7   2022-09-15T14:03:00.000Z         0.476280          7.479994e+08
# 8   2022-09-15T14:03:00.000Z        33.790925          1.079633e+09
# 9   2022-09-15T14:03:00.000Z         0.060581          3.292522e+08
# 10  2022-09-15T14:03:00.000Z         7.115684          3.518252e+08
# 11  2022-09-15T14:03:00.000Z         0.857847          4.430128e+08
# 12  2022-09-15T14:03:00.000Z         0.999981          7.598576e+08
# 13  2022-09-15T14:03:00.000Z         0.000012          3.126964e+08
# 14  2022-09-15T14:03:00.000Z         0.061688          3.914019e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       -6.5160                    -0.029119
# 1                       29.0245                    -0.114460
# 2                        4.2651                    -0.002513
# 3                        8.2595                     0.003712
# 4                        3.7118                    -0.077648
# 5                       -7.5965                     0.094611
# 6                        9.0760                    -0.518694
# 7                       -9.9749                     0.086450
# 8                      -14.7707                    -0.109971
# 9                      -21.3360                    -0.116048
# 10                       2.7201                     0.034274
# 11                      -6.1793                    -0.091240
# 12                       2.1962                     0.052320
# 13                     -11.4450                    -0.171632
# 14                       3.9987                     0.155524
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -0.847396                     4.758930
# 1                      -0.980661                    -2.688507
# 2                      -0.003716                    -0.004560
# 3                      -0.003011                     0.026436
# 4                      -1.740142                    -1.191049
# 5                       0.066314                     0.004316
# 6                      -1.371300                    -0.189293
# 7                      -1.652967                     1.260025
# 8                       0.832958                     2.016948
# 9                      -0.729793                     0.096240
# 10                     -1.956880                    -1.059077
# 11                      0.460608                     3.139748
# 12                      0.003776                     0.057717
# 13                     -1.892200                    -0.786031
# 14                      0.678303                     1.920993
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                     -15.727751                     -4.795852
# 1                     -15.570242                     18.269147
# 2                      -0.017887                      0.031930
# 3                       0.022834                      0.024837
# 4                     -12.323302                     10.430368
# 5                       0.046192                     -0.111344
# 6                     -10.922143                     -4.034733
# 7                     -13.996499                      6.173771
# 8                     -21.688281                    -14.056456
# 9                     -30.877333                     -4.675139
# 10                    -18.526560                      1.126614
# 11                     -9.258108                     11.072329
# 12                      0.104764                      0.031161
# 13                    -24.158740                     10.824865
# 14                    -10.297335                     -9.724966
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      -3.235892          3.856533e+11
# 1                      45.254072          1.943414e+11
# 2                       0.120037          6.788535e+10
# 3                      -0.066374          5.076882e+10
# 4                      26.467416          4.458335e+10
# 5                      -0.099451          2.052281e+10
# 6                       2.209548          1.659605e+10
# 7                      -2.929778          1.628023e+10
# 8                       6.360737          1.196131e+10
# 9                       6.165762          8.037294e+09
# 10                     -3.794975          7.949217e+09
# 11                    113.311457          7.492710e+09
# 12                     -0.066670          6.848618e+09
# 13                     47.229609          6.610702e+09
# 14                      2.983699          5.697878e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          39.0000                        4.228816e+11
# 1                          19.6552                        1.943414e+11
# 2                           6.8633                        6.915873e+10
# 3                           5.1346                        5.076882e+10
# 4                           4.5074                        5.526728e+10
# 5                           2.0756                        2.052281e+10
# 6                           1.6783                        3.330799e+10
# 7                           1.6465                        2.143261e+10
# 8                           1.2096                        1.728801e+10
# 9                           0.8122                        8.037294e+09
# 10                          0.8040                        8.770536e+09
# 11                          0.7572                        8.578472e+09
# 12                          0.6927                        6.848618e+09
# 13                          0.6681                        7.100388e+09
# 14                          0.5761                        5.697881e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2022-09-15T14:03:00.000Z          NaN           NaN
# 1           None  2022-09-15T14:03:00.000Z          NaN           NaN
# 2           None  2022-09-15T14:03:00.000Z       1027.0      Ethereum
# 3           None  2022-09-15T14:03:00.000Z       1027.0      Ethereum
# 4           None  2022-09-15T14:03:00.000Z          NaN           NaN
# 5           None  2022-09-15T14:03:00.000Z       1839.0           BNB
# 6           None  2022-09-15T14:03:00.000Z          NaN           NaN
# 7           None  2022-09-15T14:03:00.000Z          NaN           NaN
# 8           None  2022-09-15T14:03:00.000Z          NaN           NaN
# 9           None  2022-09-15T14:03:00.000Z          NaN           NaN
# 10          None  2022-09-15T14:03:00.000Z          NaN           NaN
# 11          None  2022-09-15T14:03:00.000Z          NaN           NaN
# 12          None  2022-09-15T14:03:00.000Z       1027.0      Ethereum
# 13          None  2022-09-15T14:03:00.000Z       1027.0      Ethereum
# 14          None  2022-09-15T14:03:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4              NaN           NaN                                         NaN
# 5              BNB           bnb                                    BUSD-BD1
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2022-09-15 14:05:10.064866
# 1  2022-09-15 14:05:10.064866
# 2  2022-09-15 14:05:10.064866
# 3  2022-09-15 14:05:10.064866
# 4  2022-09-15 14:05:10.064866
# 5  2022-09-15 14:05:10.064866
# 6  2022-09-15 14:05:10.064866
# 7  2022-09-15 14:05:10.064866
# 8  2022-09-15 14:05:10.064866
# 9  2022-09-15 14:05:10.064866
# 10 2022-09-15 14:05:10.064866
# 11 2022-09-15 14:05:10.064866
# 12 2022-09-15 14:05:10.064866
# 13 2022-09-15 14:05:10.064866
# 14 2022-09-15 14:05:10.064866

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    
    df2= pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now')
    df = df2.append(df2)

# %%
#script to automate 
import os
from time import time
from time import sleep

#for loop and 333 is number of times a day you can run the API
for i in range(333):
    api_runner()
    print('The API Runner has completed.')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# The API Runner has completed.
# The API Runner has completed.
# The API Runner has completed.
# The API Runner has completed.
# The API Runner has completed.
# The API Runner has completed.
# The API Runner has completed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_q/0jtv76z17rxccdbhkn46s_t80000gn/T/ipykernel_3754/3041558578.py in <module>
#       8     api_runner()
#       9     print('The API Runner has completed.')
# ---> 10     sleep(60) #sleep for 1 minute
#      11 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#       id         name symbol                  slug  num_market_pairs  \
# 0      1      Bitcoin    BTC               bitcoin              9740
# 1   1027     Ethereum    ETH              ethereum              6089
# 2    825       Tether   USDT                tether             39680
# 3   3408     USD Coin   USDC              usd-coin              6195
# 4   1839          BNB    BNB                   bnb              1103
# 5   4687  Binance USD   BUSD           binance-usd              5086
# 6     52          XRP    XRP                   xrp               814
# 7   2010      Cardano    ADA               cardano               569
# 8   5426       Solana    SOL                solana               383
# 9     74     Dogecoin   DOGE              dogecoin               561
# 10  6636     Polkadot    DOT          polkadot-new               410
# 11  3890      Polygon  MATIC               polygon               484
# 12  4943          Dai    DAI  multi-collateral-dai              1336
# 13  5994    Shiba Inu   SHIB             shiba-inu               413
# 14  1958         TRON    TRX                  tron               684
# 0      1      Bitcoin    BTC               bitcoin              9740
# 1   1027     Ethereum    ETH              ethereum              6089
# 2    825       Tether   USDT                tether             39680
# 3   3408     USD Coin   USDC              usd-coin              6195
# 4   1839          BNB    BNB                   bnb              1103
# 5   4687  Binance USD   BUSD           binance-usd              5086
# 6     52          XRP    XRP                   xrp               814
# 7   2010      Cardano    ADA               cardano               569
# 8   5426       Solana    SOL                solana               383
# 9     74     Dogecoin   DOGE              dogecoin               561
# 10  6636     Polkadot    DOT          polkadot-new               410
# 11  3890      Polygon  MATIC               polygon               484
# 12  4943          Dai    DAI  multi-collateral-dai              1336
# 13  5994    Shiba Inu   SHIB             shiba-inu               413
# 14  1958         TRON    TRX                  tron               684
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2018-10-08T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2019-09-20T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-04-10T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2019-04-28T00:00:00.000Z
# 12  2019-11-22T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2018-10-08T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2019-09-20T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-04-10T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2019-04-28T00:00:00.000Z
# 12  2019-11-22T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [mineable, pow, smart-contracts, ethereum-ecos...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 4   [marketplace, centralized-exchange, payments, ...    200000000.00000
# 5   [stablecoin, asset-backed-stablecoin, binance-...                NaN
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 8   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 9   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 11  [platform, enterprise-solutions, scaling, stat...  10000000000.00000
# 12  [defi, stablecoin, asset-backed-stablecoin, et...                NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 14                  [media, payments, tron-ecosystem]                NaN
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [mineable, pow, smart-contracts, ethereum-ecos...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 4   [marketplace, centralized-exchange, payments, ...    200000000.00000
# 5   [stablecoin, asset-backed-stablecoin, binance-...                NaN
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 8   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 9   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 11  [platform, enterprise-solutions, scaling, stat...  10000000000.00000
# 12  [defi, stablecoin, asset-backed-stablecoin, et...                NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 14                  [media, payments, tron-ecosystem]                NaN
#
#       circulating_supply          total_supply  platform  cmc_rank  \
# 0         19150881.00000        19150881.00000       NaN         1
# 1        122371557.43650       122371557.43650       NaN         2
# 2      67883438459.35066     69156782826.32211       NaN         3
# 3      50807456528.26229     50807456528.26229       NaN         4
# 4        161337261.09000       161337261.09000       NaN         5
# 5      20517253084.58926     20517253084.58926       NaN         6
# 6      49826021773.00000     99989302361.00000       NaN         7
# 7      34182044152.62900     34854947575.48000       NaN         8
# 8        353848267.11550       511616946.14229       NaN         9
# 9     132670764299.89409    132670764299.89409       NaN        10
# 10      1132527619.33446      1232557368.87714       NaN        11
# 11      8734317475.28493     10000000000.00000       NaN        12
# 12      6839924162.06719      6839924162.06719       NaN        13
# 13 549063278876301.93750 589735030408322.75000       NaN        14
# 14     92366671484.34125     92366665415.80617       NaN        15
# 0         19150881.00000        19150881.00000       NaN         1
# 1        122371557.43650       122371557.43650       NaN         2
# 2      67883438459.35066     69156782826.32211       NaN         3
# 3      50807456528.26229     50807456528.26229       NaN         4
# 4        161337261.09000       161337261.09000       NaN         5
# 5      20517253084.58926     20517253084.58926       NaN         6
# 6      49826021773.00000     99989302361.00000       NaN         7
# 7      34182044152.62900     34854947575.48000       NaN         8
# 8        353848267.11550       511616946.14229       NaN         9
# 9     132670764299.89409    132670764299.89409       NaN        10
# 10      1132527619.33446      1232557368.87714       NaN        11
# 11      8734317475.28493     10000000000.00000       NaN        12
# 12      6839924162.06719      6839924162.06719       NaN        13
# 13 549063278876301.93750 589735030408322.75000       NaN        14
# 14     92366671484.34125     92366665415.80617       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                   904869778.00000          6365447627.83482      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                 71659659264.00000          4373125246.45869      None
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                   904869778.00000          6365447627.83482      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                 71659659264.00000          4373125246.45869      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2022-09-15T02:26:00.000Z      20086.21755     37719571572.83210
# 1   2022-09-15T02:26:00.000Z       1611.22227     18789703865.52800
# 2   2022-09-15T02:26:00.000Z          1.00014     55809535836.12127
# 3   2022-09-15T02:26:00.000Z          0.99999      6034933916.62651
# 4   2022-09-15T02:26:00.000Z        276.01300       963370380.43727
# 5   2022-09-15T02:26:00.000Z          0.99914      9971169098.23416
# 6   2022-09-15T02:26:00.000Z          0.33700      1207202475.12731
# 7   2022-09-15T02:26:00.000Z          0.47319       732179300.43997
# 8   2022-09-15T02:26:00.000Z         33.51488       963134717.70034
# 9   2022-09-15T02:26:00.000Z          0.06035       359048609.66663
# 10  2022-09-15T02:26:00.000Z          7.03466       321313192.91903
# 11  2022-09-15T02:26:00.000Z          0.84798       405637500.02957
# 12  2022-09-15T02:26:00.000Z          0.99905       697775705.01893
# 13  2022-09-15T02:26:00.000Z          0.00001       311367632.30440
# 14  2022-09-15T02:26:00.000Z          0.06103       349859652.37644
# 0   2022-09-15T02:26:00.000Z      20086.21755     37719571572.83210
# 1   2022-09-15T02:26:00.000Z       1611.22227     18789703865.52800
# 2   2022-09-15T02:26:00.000Z          1.00014     55809535836.12127
# 3   2022-09-15T02:26:00.000Z          0.99999      6034933916.62651
# 4   2022-09-15T02:26:00.000Z        276.01300       963370380.43727
# 5   2022-09-15T02:26:00.000Z          0.99914      9971169098.23416
# 6   2022-09-15T02:26:00.000Z          0.33700      1207202475.12731
# 7   2022-09-15T02:26:00.000Z          0.47319       732179300.43997
# 8   2022-09-15T02:26:00.000Z         33.51488       963134717.70034
# 9   2022-09-15T02:26:00.000Z          0.06035       359048609.66663
# 10  2022-09-15T02:26:00.000Z          7.03466       321313192.91903
# 11  2022-09-15T02:26:00.000Z          0.84798       405637500.02957
# 12  2022-09-15T02:26:00.000Z          0.99905       697775705.01893
# 13  2022-09-15T02:26:00.000Z          0.00001       311367632.30440
# 14  2022-09-15T02:26:00.000Z          0.06103       349859652.37644
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                     -26.45510                      0.03897
# 1                     -18.83000                     -0.09766
# 2                     -22.10730                     -0.00447
# 3                     -18.85240                     -0.00506
# 4                     -15.13150                     -0.53336
# 5                     -24.44170                     -0.08409
# 6                     -16.55810                     -0.87323
# 7                     -26.89850                     -0.80167
# 8                     -45.62860                     -0.57820
# 9                     -21.94910                     -0.97646
# 10                    -32.78130                     -0.88221
# 11                    -42.90480                     -0.50219
# 12                    -18.53650                     -0.02721
# 13                    -31.94350                     -0.53287
# 14                    -13.99280                     -0.43845
# 0                     -26.45510                      0.03897
# 1                     -18.83000                     -0.09766
# 2                     -22.10730                     -0.00447
# 3                     -18.85240                     -0.00506
# 4                     -15.13150                     -0.53336
# 5                     -24.44170                     -0.08409
# 6                     -16.55810                     -0.87323
# 7                     -26.89850                     -0.80167
# 8                     -45.62860                     -0.57820
# 9                     -21.94910                     -0.97646
# 10                    -32.78130                     -0.88221
# 11                    -42.90480                     -0.50219
# 12                    -18.53650                     -0.02721
# 13                    -31.94350                     -0.53287
# 14                    -13.99280                     -0.43845
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -1.85478                      4.35521
# 1                        1.02032                     -0.84751
# 2                        0.01103                      0.00254
# 3                       -0.01695                     -0.01455
# 4                       -1.28785                     -1.42330
# 5                       -0.08645                     -0.12018
# 6                        0.56496                      1.49162
# 7                        0.28683                     -0.92560
# 8                       -0.36760                      3.11120
# 9                       -0.00187                     -1.00299
# 10                      -2.04595                     -2.40243
# 11                      -1.80370                      0.57742
# 12                      -0.11066                     -0.10025
# 13                      -1.88842                     -1.64927
# 14                      -0.29978                      0.50735
# 0                       -1.85478                      4.35521
# 1                        1.02032                     -0.84751
# 2                        0.01103                      0.00254
# 3                       -0.01695                     -0.01455
# 4                       -1.28785                     -1.42330
# 5                       -0.08645                     -0.12018
# 6                        0.56496                      1.49162
# 7                        0.28683                     -0.92560
# 8                       -0.36760                      3.11120
# 9                       -0.00187                     -1.00299
# 10                      -2.04595                     -2.40243
# 11                      -1.80370                      0.57742
# 12                      -0.11066                     -0.10025
# 13                      -1.88842                     -1.64927
# 14                      -0.29978                      0.50735
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      -16.81022                      -5.14920
# 1                      -15.29056                      20.22622
# 2                       -0.00488                       0.03523
# 3                        0.00884                       0.01311
# 4                      -13.71418                      11.12776
# 5                       -0.06862                      -0.15318
# 6                       -9.44135                      -3.79422
# 7                      -15.52760                       4.59060
# 8                      -23.26467                     -15.13420
# 9                      -23.57526                      -5.70256
# 10                     -20.13428                      -1.07761
# 11                     -11.47706                      17.08748
# 12                      -0.03827                      -0.02871
# 13                     -22.74841                      10.30389
# 14                     -11.43989                     -11.03340
# 0                      -16.81022                      -5.14920
# 1                      -15.29056                      20.22622
# 2                       -0.00488                       0.03523
# 3                        0.00884                       0.01311
# 4                      -13.71418                      11.12776
# 5                       -0.06862                      -0.15318
# 6                       -9.44135                      -3.79422
# 7                      -15.52760                       4.59060
# 8                      -23.26467                     -15.13420
# 9                      -23.57526                      -5.70256
# 10                     -20.13428                      -1.07761
# 11                     -11.47706                      17.08748
# 12                      -0.03827                      -0.02871
# 13                     -22.74841                      10.30389
# 14                     -11.43989                     -11.03340
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       -3.26165    384668762102.85425
# 1                       46.92122    197167778257.05331
# 2                        0.12741     67892702396.38782
# 3                       -0.03083     50807189090.23273
# 4                       28.17752     44531181437.15199
# 5                       -0.29739     20499546055.94763
# 6                        3.14098     16791329715.28789
# 7                       -3.35950     16174465973.04118
# 8                        9.35802     11859180610.76805
# 9                        7.16875      8007009368.49166
# 10                      -3.28148      7966942231.05101
# 11                     116.70833      7406553454.09451
# 12                      -0.14976      6833452966.48641
# 13                      47.27949      6620943027.27813
# 14                      -1.48665      5636797985.75951
# 0                       -3.26165    384668762102.85425
# 1                       46.92122    197167778257.05331
# 2                        0.12741     67892702396.38782
# 3                       -0.03083     50807189090.23273
# 4                       28.17752     44531181437.15199
# 5                       -0.29739     20499546055.94763
# 6                        3.14098     16791329715.28789
# 7                       -3.35950     16174465973.04118
# 8                        9.35802     11859180610.76805
# 9                        7.16875      8007009368.49166
# 10                      -3.28148      7966942231.05101
# 11                     116.70833      7406553454.09451
# 12                      -0.14976      6833452966.48641
# 13                      47.27949      6620943027.27813
# 14                      -1.48665      5636797985.75951
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         38.89130                  421810568618.75000
# 1                         19.92480                  197167778257.04999
# 2                          6.84760                   69166220534.49001
# 3                          5.13430                   50807189090.23000
# 4                          4.49140                   55202599989.98000
# 5                          2.07260                   20499546055.95000
# 6                          1.69770                   33699920478.87000
# 7                          1.63450                   21293371617.47000
# 8                          1.19610                   17146778242.81000
# 9                          0.80890                    8007009368.49000
# 10                         0.80510                    8670617110.49000
# 11                         0.74700                    8479830822.56000
# 12                         0.69030                    6833452966.49000
# 13                         0.66910                    7111388045.32000
# 14                         0.56850                    5636797615.42000
# 0                         38.89130                  421810568618.75000
# 1                         19.92480                  197167778257.04999
# 2                          6.84760                   69166220534.49001
# 3                          5.13430                   50807189090.23000
# 4                          4.49140                   55202599989.98000
# 5                          2.07260                   20499546055.95000
# 6                          1.69770                   33699920478.87000
# 7                          1.63450                   21293371617.47000
# 8                          1.19610                   17146778242.81000
# 9                          0.80890                    8007009368.49000
# 10                         0.80510                    8670617110.49000
# 11                         0.74700                    8479830822.56000
# 12                         0.69030                    6833452966.49000
# 13                         0.66910                    7111388045.32000
# 14                         0.56850                    5636797615.42000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 1           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 2           None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 3           None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 4           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 5           None  2022-09-15T02:26:00.000Z   1839.00000           BNB
# 6           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 7           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 8           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 9           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 10          None  2022-09-15T02:26:00.000Z          NaN           NaN
# 11          None  2022-09-15T02:26:00.000Z          NaN           NaN
# 12          None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 13          None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 14          None  2022-09-15T02:26:00.000Z          NaN           NaN
# 0           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 1           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 2           None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 3           None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 4           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 5           None  2022-09-15T02:26:00.000Z   1839.00000           BNB
# 6           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 7           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 8           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 9           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 10          None  2022-09-15T02:26:00.000Z          NaN           NaN
# 11          None  2022-09-15T02:26:00.000Z          NaN           NaN
# 12          None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 13          None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 14          None  2022-09-15T02:26:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4              NaN           NaN                                         NaN
# 5              BNB           bnb                                    BUSD-BD1
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4              NaN           NaN                                         NaN
# 5              BNB           bnb                                    BUSD-BD1
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2022-09-15 02:28:08.062603
# 1  2022-09-15 02:28:08.062603
# 2  2022-09-15 02:28:08.062603
# 3  2022-09-15 02:28:08.062603
# 4  2022-09-15 02:28:08.062603
# 5  2022-09-15 02:28:08.062603
# 6  2022-09-15 02:28:08.062603
# 7  2022-09-15 02:28:08.062603
# 8  2022-09-15 02:28:08.062603
# 9  2022-09-15 02:28:08.062603
# 10 2022-09-15 02:28:08.062603
# 11 2022-09-15 02:28:08.062603
# 12 2022-09-15 02:28:08.062603
# 13 2022-09-15 02:28:08.062603
# 14 2022-09-15 02:28:08.062603
# 0  2022-09-15 02:28:08.062603
# 1  2022-09-15 02:28:08.062603
# 2  2022-09-15 02:28:08.062603
# 3  2022-09-15 02:28:08.062603
# 4  2022-09-15 02:28:08.062603
# 5  2022-09-15 02:28:08.062603
# 6  2022-09-15 02:28:08.062603
# 7  2022-09-15 02:28:08.062603
# 8  2022-09-15 02:28:08.062603
# 9  2022-09-15 02:28:08.062603
# 10 2022-09-15 02:28:08.062603
# 11 2022-09-15 02:28:08.062603
# 12 2022-09-15 02:28:08.062603
# 13 2022-09-15 02:28:08.062603
# 14 2022-09-15 02:28:08.062603

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id         name symbol                  slug  num_market_pairs  \
# 0      1      Bitcoin    BTC               bitcoin              9740
# 1   1027     Ethereum    ETH              ethereum              6089
# 2    825       Tether   USDT                tether             39680
# 3   3408     USD Coin   USDC              usd-coin              6195
# 4   1839          BNB    BNB                   bnb              1103
# 5   4687  Binance USD   BUSD           binance-usd              5086
# 6     52          XRP    XRP                   xrp               814
# 7   2010      Cardano    ADA               cardano               569
# 8   5426       Solana    SOL                solana               383
# 9     74     Dogecoin   DOGE              dogecoin               561
# 10  6636     Polkadot    DOT          polkadot-new               410
# 11  3890      Polygon  MATIC               polygon               484
# 12  4943          Dai    DAI  multi-collateral-dai              1336
# 13  5994    Shiba Inu   SHIB             shiba-inu               413
# 14  1958         TRON    TRX                  tron               684
# 0      1      Bitcoin    BTC               bitcoin              9740
# 1   1027     Ethereum    ETH              ethereum              6089
# 2    825       Tether   USDT                tether             39680
# 3   3408     USD Coin   USDC              usd-coin              6195
# 4   1839          BNB    BNB                   bnb              1103
# 5   4687  Binance USD   BUSD           binance-usd              5086
# 6     52          XRP    XRP                   xrp               814
# 7   2010      Cardano    ADA               cardano               569
# 8   5426       Solana    SOL                solana               383
# 9     74     Dogecoin   DOGE              dogecoin               561
# 10  6636     Polkadot    DOT          polkadot-new               410
# 11  3890      Polygon  MATIC               polygon               484
# 12  4943          Dai    DAI  multi-collateral-dai              1336
# 13  5994    Shiba Inu   SHIB             shiba-inu               413
# 14  1958         TRON    TRX                  tron               684
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2018-10-08T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2019-09-20T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-04-10T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2019-04-28T00:00:00.000Z
# 12  2019-11-22T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2018-10-08T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2019-09-20T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2020-04-10T00:00:00.000Z
# 9   2013-12-15T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2019-04-28T00:00:00.000Z
# 12  2019-11-22T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [mineable, pow, smart-contracts, ethereum-ecos...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 4   [marketplace, centralized-exchange, payments, ...    200000000.00000
# 5   [stablecoin, asset-backed-stablecoin, binance-...                NaN
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 8   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 9   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 11  [platform, enterprise-solutions, scaling, stat...  10000000000.00000
# 12  [defi, stablecoin, asset-backed-stablecoin, et...                NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 14                  [media, payments, tron-ecosystem]                NaN
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [mineable, pow, smart-contracts, ethereum-ecos...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 4   [marketplace, centralized-exchange, payments, ...    200000000.00000
# 5   [stablecoin, asset-backed-stablecoin, binance-...                NaN
# 6   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 8   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 9   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 11  [platform, enterprise-solutions, scaling, stat...  10000000000.00000
# 12  [defi, stablecoin, asset-backed-stablecoin, et...                NaN
# 13      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
# 14                  [media, payments, tron-ecosystem]                NaN
#
#       circulating_supply          total_supply  platform  cmc_rank  \
# 0         19150881.00000        19150881.00000       NaN         1
# 1        122371557.43650       122371557.43650       NaN         2
# 2      67883438459.35066     69156782826.32211       NaN         3
# 3      50807456528.26229     50807456528.26229       NaN         4
# 4        161337261.09000       161337261.09000       NaN         5
# 5      20517253084.58926     20517253084.58926       NaN         6
# 6      49826021773.00000     99989302361.00000       NaN         7
# 7      34182044152.62900     34854947575.48000       NaN         8
# 8        353848267.11550       511616946.14229       NaN         9
# 9     132670764299.89409    132670764299.89409       NaN        10
# 10      1132527619.33446      1232557368.87714       NaN        11
# 11      8734317475.28493     10000000000.00000       NaN        12
# 12      6839924162.06719      6839924162.06719       NaN        13
# 13 549063278876301.93750 589735030408322.75000       NaN        14
# 14     92366671484.34125     92366665415.80617       NaN        15
# 0         19150881.00000        19150881.00000       NaN         1
# 1        122371557.43650       122371557.43650       NaN         2
# 2      67883438459.35066     69156782826.32211       NaN         3
# 3      50807456528.26229     50807456528.26229       NaN         4
# 4        161337261.09000       161337261.09000       NaN         5
# 5      20517253084.58926     20517253084.58926       NaN         6
# 6      49826021773.00000     99989302361.00000       NaN         7
# 7      34182044152.62900     34854947575.48000       NaN         8
# 8        353848267.11550       511616946.14229       NaN         9
# 9     132670764299.89409    132670764299.89409       NaN        10
# 10      1132527619.33446      1232557368.87714       NaN        11
# 11      8734317475.28493     10000000000.00000       NaN        12
# 12      6839924162.06719      6839924162.06719       NaN        13
# 13 549063278876301.93750 589735030408322.75000       NaN        14
# 14     92366671484.34125     92366665415.80617       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                   904869778.00000          6365447627.83482      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                 71659659264.00000          4373125246.45869      None
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                   904869778.00000          6365447627.83482      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                 71659659264.00000          4373125246.45869      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2022-09-15T02:26:00.000Z      20086.21755     37719571572.83210
# 1   2022-09-15T02:26:00.000Z       1611.22227     18789703865.52800
# 2   2022-09-15T02:26:00.000Z          1.00014     55809535836.12127
# 3   2022-09-15T02:26:00.000Z          0.99999      6034933916.62651
# 4   2022-09-15T02:26:00.000Z        276.01300       963370380.43727
# 5   2022-09-15T02:26:00.000Z          0.99914      9971169098.23416
# 6   2022-09-15T02:26:00.000Z          0.33700      1207202475.12731
# 7   2022-09-15T02:26:00.000Z          0.47319       732179300.43997
# 8   2022-09-15T02:26:00.000Z         33.51488       963134717.70034
# 9   2022-09-15T02:26:00.000Z          0.06035       359048609.66663
# 10  2022-09-15T02:26:00.000Z          7.03466       321313192.91903
# 11  2022-09-15T02:26:00.000Z          0.84798       405637500.02957
# 12  2022-09-15T02:26:00.000Z          0.99905       697775705.01893
# 13  2022-09-15T02:26:00.000Z          0.00001       311367632.30440
# 14  2022-09-15T02:26:00.000Z          0.06103       349859652.37644
# 0   2022-09-15T02:26:00.000Z      20086.21755     37719571572.83210
# 1   2022-09-15T02:26:00.000Z       1611.22227     18789703865.52800
# 2   2022-09-15T02:26:00.000Z          1.00014     55809535836.12127
# 3   2022-09-15T02:26:00.000Z          0.99999      6034933916.62651
# 4   2022-09-15T02:26:00.000Z        276.01300       963370380.43727
# 5   2022-09-15T02:26:00.000Z          0.99914      9971169098.23416
# 6   2022-09-15T02:26:00.000Z          0.33700      1207202475.12731
# 7   2022-09-15T02:26:00.000Z          0.47319       732179300.43997
# 8   2022-09-15T02:26:00.000Z         33.51488       963134717.70034
# 9   2022-09-15T02:26:00.000Z          0.06035       359048609.66663
# 10  2022-09-15T02:26:00.000Z          7.03466       321313192.91903
# 11  2022-09-15T02:26:00.000Z          0.84798       405637500.02957
# 12  2022-09-15T02:26:00.000Z          0.99905       697775705.01893
# 13  2022-09-15T02:26:00.000Z          0.00001       311367632.30440
# 14  2022-09-15T02:26:00.000Z          0.06103       349859652.37644
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                     -26.45510                      0.03897
# 1                     -18.83000                     -0.09766
# 2                     -22.10730                     -0.00447
# 3                     -18.85240                     -0.00506
# 4                     -15.13150                     -0.53336
# 5                     -24.44170                     -0.08409
# 6                     -16.55810                     -0.87323
# 7                     -26.89850                     -0.80167
# 8                     -45.62860                     -0.57820
# 9                     -21.94910                     -0.97646
# 10                    -32.78130                     -0.88221
# 11                    -42.90480                     -0.50219
# 12                    -18.53650                     -0.02721
# 13                    -31.94350                     -0.53287
# 14                    -13.99280                     -0.43845
# 0                     -26.45510                      0.03897
# 1                     -18.83000                     -0.09766
# 2                     -22.10730                     -0.00447
# 3                     -18.85240                     -0.00506
# 4                     -15.13150                     -0.53336
# 5                     -24.44170                     -0.08409
# 6                     -16.55810                     -0.87323
# 7                     -26.89850                     -0.80167
# 8                     -45.62860                     -0.57820
# 9                     -21.94910                     -0.97646
# 10                    -32.78130                     -0.88221
# 11                    -42.90480                     -0.50219
# 12                    -18.53650                     -0.02721
# 13                    -31.94350                     -0.53287
# 14                    -13.99280                     -0.43845
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -1.85478                      4.35521
# 1                        1.02032                     -0.84751
# 2                        0.01103                      0.00254
# 3                       -0.01695                     -0.01455
# 4                       -1.28785                     -1.42330
# 5                       -0.08645                     -0.12018
# 6                        0.56496                      1.49162
# 7                        0.28683                     -0.92560
# 8                       -0.36760                      3.11120
# 9                       -0.00187                     -1.00299
# 10                      -2.04595                     -2.40243
# 11                      -1.80370                      0.57742
# 12                      -0.11066                     -0.10025
# 13                      -1.88842                     -1.64927
# 14                      -0.29978                      0.50735
# 0                       -1.85478                      4.35521
# 1                        1.02032                     -0.84751
# 2                        0.01103                      0.00254
# 3                       -0.01695                     -0.01455
# 4                       -1.28785                     -1.42330
# 5                       -0.08645                     -0.12018
# 6                        0.56496                      1.49162
# 7                        0.28683                     -0.92560
# 8                       -0.36760                      3.11120
# 9                       -0.00187                     -1.00299
# 10                      -2.04595                     -2.40243
# 11                      -1.80370                      0.57742
# 12                      -0.11066                     -0.10025
# 13                      -1.88842                     -1.64927
# 14                      -0.29978                      0.50735
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      -16.81022                      -5.14920
# 1                      -15.29056                      20.22622
# 2                       -0.00488                       0.03523
# 3                        0.00884                       0.01311
# 4                      -13.71418                      11.12776
# 5                       -0.06862                      -0.15318
# 6                       -9.44135                      -3.79422
# 7                      -15.52760                       4.59060
# 8                      -23.26467                     -15.13420
# 9                      -23.57526                      -5.70256
# 10                     -20.13428                      -1.07761
# 11                     -11.47706                      17.08748
# 12                      -0.03827                      -0.02871
# 13                     -22.74841                      10.30389
# 14                     -11.43989                     -11.03340
# 0                      -16.81022                      -5.14920
# 1                      -15.29056                      20.22622
# 2                       -0.00488                       0.03523
# 3                        0.00884                       0.01311
# 4                      -13.71418                      11.12776
# 5                       -0.06862                      -0.15318
# 6                       -9.44135                      -3.79422
# 7                      -15.52760                       4.59060
# 8                      -23.26467                     -15.13420
# 9                      -23.57526                      -5.70256
# 10                     -20.13428                      -1.07761
# 11                     -11.47706                      17.08748
# 12                      -0.03827                      -0.02871
# 13                     -22.74841                      10.30389
# 14                     -11.43989                     -11.03340
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       -3.26165    384668762102.85425
# 1                       46.92122    197167778257.05331
# 2                        0.12741     67892702396.38782
# 3                       -0.03083     50807189090.23273
# 4                       28.17752     44531181437.15199
# 5                       -0.29739     20499546055.94763
# 6                        3.14098     16791329715.28789
# 7                       -3.35950     16174465973.04118
# 8                        9.35802     11859180610.76805
# 9                        7.16875      8007009368.49166
# 10                      -3.28148      7966942231.05101
# 11                     116.70833      7406553454.09451
# 12                      -0.14976      6833452966.48641
# 13                      47.27949      6620943027.27813
# 14                      -1.48665      5636797985.75951
# 0                       -3.26165    384668762102.85425
# 1                       46.92122    197167778257.05331
# 2                        0.12741     67892702396.38782
# 3                       -0.03083     50807189090.23273
# 4                       28.17752     44531181437.15199
# 5                       -0.29739     20499546055.94763
# 6                        3.14098     16791329715.28789
# 7                       -3.35950     16174465973.04118
# 8                        9.35802     11859180610.76805
# 9                        7.16875      8007009368.49166
# 10                      -3.28148      7966942231.05101
# 11                     116.70833      7406553454.09451
# 12                      -0.14976      6833452966.48641
# 13                      47.27949      6620943027.27813
# 14                      -1.48665      5636797985.75951
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         38.89130                  421810568618.75000
# 1                         19.92480                  197167778257.04999
# 2                          6.84760                   69166220534.49001
# 3                          5.13430                   50807189090.23000
# 4                          4.49140                   55202599989.98000
# 5                          2.07260                   20499546055.95000
# 6                          1.69770                   33699920478.87000
# 7                          1.63450                   21293371617.47000
# 8                          1.19610                   17146778242.81000
# 9                          0.80890                    8007009368.49000
# 10                         0.80510                    8670617110.49000
# 11                         0.74700                    8479830822.56000
# 12                         0.69030                    6833452966.49000
# 13                         0.66910                    7111388045.32000
# 14                         0.56850                    5636797615.42000
# 0                         38.89130                  421810568618.75000
# 1                         19.92480                  197167778257.04999
# 2                          6.84760                   69166220534.49001
# 3                          5.13430                   50807189090.23000
# 4                          4.49140                   55202599989.98000
# 5                          2.07260                   20499546055.95000
# 6                          1.69770                   33699920478.87000
# 7                          1.63450                   21293371617.47000
# 8                          1.19610                   17146778242.81000
# 9                          0.80890                    8007009368.49000
# 10                         0.80510                    8670617110.49000
# 11                         0.74700                    8479830822.56000
# 12                         0.69030                    6833452966.49000
# 13                         0.66910                    7111388045.32000
# 14                         0.56850                    5636797615.42000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 1           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 2           None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 3           None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 4           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 5           None  2022-09-15T02:26:00.000Z   1839.00000           BNB
# 6           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 7           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 8           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 9           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 10          None  2022-09-15T02:26:00.000Z          NaN           NaN
# 11          None  2022-09-15T02:26:00.000Z          NaN           NaN
# 12          None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 13          None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 14          None  2022-09-15T02:26:00.000Z          NaN           NaN
# 0           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 1           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 2           None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 3           None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 4           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 5           None  2022-09-15T02:26:00.000Z   1839.00000           BNB
# 6           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 7           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 8           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 9           None  2022-09-15T02:26:00.000Z          NaN           NaN
# 10          None  2022-09-15T02:26:00.000Z          NaN           NaN
# 11          None  2022-09-15T02:26:00.000Z          NaN           NaN
# 12          None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 13          None  2022-09-15T02:26:00.000Z   1027.00000      Ethereum
# 14          None  2022-09-15T02:26:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4              NaN           NaN                                         NaN
# 5              BNB           bnb                                    BUSD-BD1
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4              NaN           NaN                                         NaN
# 5              BNB           bnb                                    BUSD-BD1
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x6b175474e89094c44da98b954eedeac495271d0f
# 13             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2022-09-15 02:28:08.062603
# 1  2022-09-15 02:28:08.062603
# 2  2022-09-15 02:28:08.062603
# 3  2022-09-15 02:28:08.062603
# 4  2022-09-15 02:28:08.062603
# 5  2022-09-15 02:28:08.062603
# 6  2022-09-15 02:28:08.062603
# 7  2022-09-15 02:28:08.062603
# 8  2022-09-15 02:28:08.062603
# 9  2022-09-15 02:28:08.062603
# 10 2022-09-15 02:28:08.062603
# 11 2022-09-15 02:28:08.062603
# 12 2022-09-15 02:28:08.062603
# 13 2022-09-15 02:28:08.062603
# 14 2022-09-15 02:28:08.062603
# 0  2022-09-15 02:28:08.062603
# 1  2022-09-15 02:28:08.062603
# 2  2022-09-15 02:28:08.062603
# 3  2022-09-15 02:28:08.062603
# 4  2022-09-15 02:28:08.062603
# 5  2022-09-15 02:28:08.062603
# 6  2022-09-15 02:28:08.062603
# 7  2022-09-15 02:28:08.062603
# 8  2022-09-15 02:28:08.062603
# 9  2022-09-15 02:28:08.062603
# 10 2022-09-15 02:28:08.062603
# 11 2022-09-15 02:28:08.062603
# 12 2022-09-15 02:28:08.062603
# 13 2022-09-15 02:28:08.062603
# 14 2022-09-15 02:28:08.062603

# %%
df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.03897                      -1.85478
# Ethereum                        -0.09766                       1.02032
# Tether                          -0.00447                       0.01103
# USD Coin                        -0.00506                      -0.01695
# BNB                             -0.53336                      -1.28785
# Binance USD                     -0.08409                      -0.08645
# XRP                             -0.87323                       0.56496
# Cardano                         -0.80167                       0.28683
# Solana                          -0.57820                      -0.36760
# Dogecoin                        -0.97646                      -0.00187
# Polkadot                        -0.88221                      -2.04595
# Polygon                         -0.50219                      -1.80370
# Dai                             -0.02721                      -0.11066
# Shiba Inu                       -0.53287                      -1.88842
# TRON                            -0.43845                      -0.29978
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                          4.35521                     -16.81022
# Ethereum                        -0.84751                     -15.29056
# Tether                           0.00254                      -0.00488
# USD Coin                        -0.01455                       0.00884
# BNB                             -1.42330                     -13.71418
# Binance USD                     -0.12018                      -0.06862
# XRP                              1.49162                      -9.44135
# Cardano                         -0.92560                     -15.52760
# Solana                           3.11120                     -23.26467
# Dogecoin                        -1.00299                     -23.57526
# Polkadot                        -2.40243                     -20.13428
# Polygon                          0.57742                     -11.47706
# Dai                             -0.10025                      -0.03827
# Shiba Inu                       -1.64927                     -22.74841
# TRON                             0.50735                     -11.43989
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          -5.14920                      -3.26165
# Ethereum                         20.22622                      46.92122
# Tether                            0.03523                       0.12741
# USD Coin                          0.01311                      -0.03083
# BNB                              11.12776                      28.17752
# Binance USD                      -0.15318                      -0.29739
# XRP                              -3.79422                       3.14098
# Cardano                           4.59060                      -3.35950
# Solana                          -15.13420                       9.35802
# Dogecoin                         -5.70256                       7.16875
# Polkadot                         -1.07761                      -3.28148
# Polygon                          17.08748                     116.70833
# Dai                              -0.02871                      -0.14976
# Shiba Inu                        10.30389                      47.27949
# TRON                            -11.03340                      -1.48665

# %%
df = df.stack()

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
df3 = df.to_frame(name='name')
df3
# Out:
#                                                                                     name
# 0  id                                                                                  1
#    name                                                                          Bitcoin
#    symbol                                                                            BTC
#    slug                                                                          bitcoin
#    num_market_pairs                                                                 9740
#    date_added                                                   2013-04-28T00:00:00.000Z
#    tags                                [mineable, pow, sha-256, store-of-value, state...
#    max_supply                                                             21000000.00000
#    circulating_supply                                                     19150881.00000
#    total_supply                                                           19150881.00000
#    cmc_rank                                                                            1
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                           20086.21755
#    quote.USD.volume_24h                                                37719571572.83210
#    quote.USD.volume_change_24h                                                 -26.45510
#    quote.USD.percent_change_1h                                                   0.03897
#    quote.USD.percent_change_24h                                                 -1.85478
#    quote.USD.percent_change_7d                                                   4.35521
#    quote.USD.percent_change_30d                                                -16.81022
#    quote.USD.percent_change_60d                                                 -5.14920
#    quote.USD.percent_change_90d                                                 -3.26165
#    quote.USD.market_cap                                               384668762102.85425
#    quote.USD.market_cap_dominance                                               38.89130
#    quote.USD.fully_diluted_market_cap                                 421810568618.75000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 1  id                                                                               1027
#    name                                                                         Ethereum
#    symbol                                                                            ETH
#    slug                                                                         ethereum
#    num_market_pairs                                                                 6089
#    date_added                                                   2015-08-07T00:00:00.000Z
#    tags                                [mineable, pow, smart-contracts, ethereum-ecos...
#    circulating_supply                                                    122371557.43650
#    total_supply                                                          122371557.43650
#    cmc_rank                                                                            2
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                            1611.22227
#    quote.USD.volume_24h                                                18789703865.52800
#    quote.USD.volume_change_24h                                                 -18.83000
#    quote.USD.percent_change_1h                                                  -0.09766
#    quote.USD.percent_change_24h                                                  1.02032
#    quote.USD.percent_change_7d                                                  -0.84751
#    quote.USD.percent_change_30d                                                -15.29056
#    quote.USD.percent_change_60d                                                 20.22622
#    quote.USD.percent_change_90d                                                 46.92122
#    quote.USD.market_cap                                               197167778257.05331
#    quote.USD.market_cap_dominance                                               19.92480
#    quote.USD.fully_diluted_market_cap                                 197167778257.04999
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 2  id                                                                                825
#    name                                                                           Tether
#    symbol                                                                           USDT
#    slug                                                                           tether
#    num_market_pairs                                                                39680
#    date_added                                                   2015-02-25T00:00:00.000Z
#    tags                                [payments, stablecoin, asset-backed-stablecoin...
#    circulating_supply                                                  67883438459.35066
#    total_supply                                                        69156782826.32211
#    cmc_rank                                                                            3
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               1.00014
#    quote.USD.volume_24h                                                55809535836.12127
#    quote.USD.volume_change_24h                                                 -22.10730
#    quote.USD.percent_change_1h                                                  -0.00447
#    quote.USD.percent_change_24h                                                  0.01103
#    quote.USD.percent_change_7d                                                   0.00254
#    quote.USD.percent_change_30d                                                 -0.00488
#    quote.USD.percent_change_60d                                                  0.03523
#    quote.USD.percent_change_90d                                                  0.12741
#    quote.USD.market_cap                                                67892702396.38782
#    quote.USD.market_cap_dominance                                                6.84760
#    quote.USD.fully_diluted_market_cap                                  69166220534.49001
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    platform.id                                                                1027.00000
#    platform.name                                                                Ethereum
#    platform.symbol                                                                   ETH
#    platform.slug                                                                ethereum
#    platform.token_address                     0xdac17f958d2ee523a2206206994597c13d831ec7
#    timestamp                                                  2022-09-15 02:28:08.062603
# 3  id                                                                               3408
#    name                                                                         USD Coin
#    symbol                                                                           USDC
#    slug                                                                         usd-coin
#    num_market_pairs                                                                 6195
#    date_added                                                   2018-10-08T00:00:00.000Z
#    tags                                [medium-of-exchange, stablecoin, asset-backed-...
#    circulating_supply                                                  50807456528.26229
#    total_supply                                                        50807456528.26229
#    cmc_rank                                                                            4
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.99999
#    quote.USD.volume_24h                                                 6034933916.62651
#    quote.USD.volume_change_24h                                                 -18.85240
#    quote.USD.percent_change_1h                                                  -0.00506
#    quote.USD.percent_change_24h                                                 -0.01695
#    quote.USD.percent_change_7d                                                  -0.01455
#    quote.USD.percent_change_30d                                                  0.00884
#    quote.USD.percent_change_60d                                                  0.01311
#    quote.USD.percent_change_90d                                                 -0.03083
#    quote.USD.market_cap                                                50807189090.23273
#    quote.USD.market_cap_dominance                                                5.13430
#    quote.USD.fully_diluted_market_cap                                  50807189090.23000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    platform.id                                                                1027.00000
#    platform.name                                                                Ethereum
#    platform.symbol                                                                   ETH
#    platform.slug                                                                ethereum
#    platform.token_address                     0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#    timestamp                                                  2022-09-15 02:28:08.062603
# 4  id                                                                               1839
#    name                                                                              BNB
#    symbol                                                                            BNB
#    slug                                                                              bnb
#    num_market_pairs                                                                 1103
#    date_added                                                   2017-07-25T00:00:00.000Z
#    tags                                [marketplace, centralized-exchange, payments, ...
#    max_supply                                                            200000000.00000
#    circulating_supply                                                    161337261.09000
#    total_supply                                                          161337261.09000
#    cmc_rank                                                                            5
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                             276.01300
#    quote.USD.volume_24h                                                  963370380.43727
#    quote.USD.volume_change_24h                                                 -15.13150
#    quote.USD.percent_change_1h                                                  -0.53336
#    quote.USD.percent_change_24h                                                 -1.28785
#    quote.USD.percent_change_7d                                                  -1.42330
#    quote.USD.percent_change_30d                                                -13.71418
#    quote.USD.percent_change_60d                                                 11.12776
#    quote.USD.percent_change_90d                                                 28.17752
#    quote.USD.market_cap                                                44531181437.15199
#    quote.USD.market_cap_dominance                                                4.49140
#    quote.USD.fully_diluted_market_cap                                  55202599989.98000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 5  id                                                                               4687
#    name                                                                      Binance USD
#    symbol                                                                           BUSD
#    slug                                                                      binance-usd
#    num_market_pairs                                                                 5086
#    date_added                                                   2019-09-20T00:00:00.000Z
#    tags                                [stablecoin, asset-backed-stablecoin, binance-...
#    circulating_supply                                                  20517253084.58926
#    total_supply                                                        20517253084.58926
#    cmc_rank                                                                            6
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.99914
#    quote.USD.volume_24h                                                 9971169098.23416
#    quote.USD.volume_change_24h                                                 -24.44170
#    quote.USD.percent_change_1h                                                  -0.08409
#    quote.USD.percent_change_24h                                                 -0.08645
#    quote.USD.percent_change_7d                                                  -0.12018
#    quote.USD.percent_change_30d                                                 -0.06862
#    quote.USD.percent_change_60d                                                 -0.15318
#    quote.USD.percent_change_90d                                                 -0.29739
#    quote.USD.market_cap                                                20499546055.94763
#    quote.USD.market_cap_dominance                                                2.07260
#    quote.USD.fully_diluted_market_cap                                  20499546055.95000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    platform.id                                                                1839.00000
#    platform.name                                                                     BNB
#    platform.symbol                                                                   BNB
#    platform.slug                                                                     bnb
#    platform.token_address                                                       BUSD-BD1
#    timestamp                                                  2022-09-15 02:28:08.062603
# 6  id                                                                                 52
#    name                                                                              XRP
#    symbol                                                                            XRP
#    slug                                                                              xrp
#    num_market_pairs                                                                  814
#    date_added                                                   2013-08-04T00:00:00.000Z
#    tags                                [medium-of-exchange, enterprise-solutions, arr...
#    max_supply                                                         100000000000.00000
#    circulating_supply                                                  49826021773.00000
#    total_supply                                                        99989302361.00000
#    cmc_rank                                                                            7
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.33700
#    quote.USD.volume_24h                                                 1207202475.12731
#    quote.USD.volume_change_24h                                                 -16.55810
#    quote.USD.percent_change_1h                                                  -0.87323
#    quote.USD.percent_change_24h                                                  0.56496
#    quote.USD.percent_change_7d                                                   1.49162
#    quote.USD.percent_change_30d                                                 -9.44135
#    quote.USD.percent_change_60d                                                 -3.79422
#    quote.USD.percent_change_90d                                                  3.14098
#    quote.USD.market_cap                                                16791329715.28789
#    quote.USD.market_cap_dominance                                                1.69770
#    quote.USD.fully_diluted_market_cap                                  33699920478.87000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 7  id                                                                               2010
#    name                                                                          Cardano
#    symbol                                                                            ADA
#    slug                                                                          cardano
#    num_market_pairs                                                                  569
#    date_added                                                   2017-10-01T00:00:00.000Z
#    tags                                [dpos, pos, platform, research, smart-contract...
#    max_supply                                                          45000000000.00000
#    circulating_supply                                                  34182044152.62900
#    total_supply                                                        34854947575.48000
#    cmc_rank                                                                            8
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.47319
#    quote.USD.volume_24h                                                  732179300.43997
#    quote.USD.volume_change_24h                                                 -26.89850
#    quote.USD.percent_change_1h                                                  -0.80167
#    quote.USD.percent_change_24h                                                  0.28683
#    quote.USD.percent_change_7d                                                  -0.92560
#    quote.USD.percent_change_30d                                                -15.52760
#    quote.USD.percent_change_60d                                                  4.59060
#    quote.USD.percent_change_90d                                                 -3.35950
#    quote.USD.market_cap                                                16174465973.04118
#    quote.USD.market_cap_dominance                                                1.63450
#    quote.USD.fully_diluted_market_cap                                  21293371617.47000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 8  id                                                                               5426
#    name                                                                           Solana
#    symbol                                                                            SOL
#    slug                                                                           solana
#    num_market_pairs                                                                  383
#    date_added                                                   2020-04-10T00:00:00.000Z
#    tags                                [pos, platform, solana-ecosystem, cms-holdings...
#    circulating_supply                                                    353848267.11550
#    total_supply                                                          511616946.14229
#    cmc_rank                                                                            9
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                              33.51488
#    quote.USD.volume_24h                                                  963134717.70034
#    quote.USD.volume_change_24h                                                 -45.62860
#    quote.USD.percent_change_1h                                                  -0.57820
#    quote.USD.percent_change_24h                                                 -0.36760
#    quote.USD.percent_change_7d                                                   3.11120
#    quote.USD.percent_change_30d                                                -23.26467
#    quote.USD.percent_change_60d                                                -15.13420
#    quote.USD.percent_change_90d                                                  9.35802
#    quote.USD.market_cap                                                11859180610.76805
#    quote.USD.market_cap_dominance                                                1.19610
#    quote.USD.fully_diluted_market_cap                                  17146778242.81000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 9  id                                                                                 74
#    name                                                                         Dogecoin
#    symbol                                                                           DOGE
#    slug                                                                         dogecoin
#    num_market_pairs                                                                  561
#    date_added                                                   2013-12-15T00:00:00.000Z
#    tags                                [mineable, pow, scrypt, medium-of-exchange, me...
#    circulating_supply                                                 132670764299.89409
#    total_supply                                                       132670764299.89409
#    cmc_rank                                                                           10
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.06035
#    quote.USD.volume_24h                                                  359048609.66663
#    quote.USD.volume_change_24h                                                 -21.94910
#    quote.USD.percent_change_1h                                                  -0.97646
#    quote.USD.percent_change_24h                                                 -0.00187
#    quote.USD.percent_change_7d                                                  -1.00299
#    quote.USD.percent_change_30d                                                -23.57526
#    quote.USD.percent_change_60d                                                 -5.70256
#    quote.USD.percent_change_90d                                                  7.16875
#    quote.USD.market_cap                                                 8007009368.49166
#    quote.USD.market_cap_dominance                                                0.80890
#    quote.USD.fully_diluted_market_cap                                   8007009368.49000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 10 id                                                                               6636
#    name                                                                         Polkadot
#    symbol                                                                            DOT
#    slug                                                                     polkadot-new
#    num_market_pairs                                                                  410
#    date_added                                                   2020-08-19T00:00:00.000Z
#    tags                                [substrate, polkadot, binance-chain, polkadot-...
#    circulating_supply                                                   1132527619.33446
#    total_supply                                                         1232557368.87714
#    cmc_rank                                                                           11
#    self_reported_circulating_supply                                      904869778.00000
#    self_reported_market_cap                                             6365447627.83482
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               7.03466
#    quote.USD.volume_24h                                                  321313192.91903
#    quote.USD.volume_change_24h                                                 -32.78130
#    quote.USD.percent_change_1h                                                  -0.88221
#    quote.USD.percent_change_24h                                                 -2.04595
#    quote.USD.percent_change_7d                                                  -2.40243
#    quote.USD.percent_change_30d                                                -20.13428
#    quote.USD.percent_change_60d                                                 -1.07761
#    quote.USD.percent_change_90d                                                 -3.28148
#    quote.USD.market_cap                                                 7966942231.05101
#    quote.USD.market_cap_dominance                                                0.80510
#    quote.USD.fully_diluted_market_cap                                   8670617110.49000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 11 id                                                                               3890
#    name                                                                          Polygon
#    symbol                                                                          MATIC
#    slug                                                                          polygon
#    num_market_pairs                                                                  484
#    date_added                                                   2019-04-28T00:00:00.000Z
#    tags                                [platform, enterprise-solutions, scaling, stat...
#    max_supply                                                          10000000000.00000
#    circulating_supply                                                   8734317475.28493
#    total_supply                                                        10000000000.00000
#    cmc_rank                                                                           12
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.84798
#    quote.USD.volume_24h                                                  405637500.02957
#    quote.USD.volume_change_24h                                                 -42.90480
#    quote.USD.percent_change_1h                                                  -0.50219
#    quote.USD.percent_change_24h                                                 -1.80370
#    quote.USD.percent_change_7d                                                   0.57742
#    quote.USD.percent_change_30d                                                -11.47706
#    quote.USD.percent_change_60d                                                 17.08748
#    quote.USD.percent_change_90d                                                116.70833
#    quote.USD.market_cap                                                 7406553454.09451
#    quote.USD.market_cap_dominance                                                0.74700
#    quote.USD.fully_diluted_market_cap                                   8479830822.56000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 12 id                                                                               4943
#    name                                                                              Dai
#    symbol                                                                            DAI
#    slug                                                             multi-collateral-dai
#    num_market_pairs                                                                 1336
#    date_added                                                   2019-11-22T00:00:00.000Z
#    tags                                [defi, stablecoin, asset-backed-stablecoin, et...
#    circulating_supply                                                   6839924162.06719
#    total_supply                                                         6839924162.06719
#    cmc_rank                                                                           13
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.99905
#    quote.USD.volume_24h                                                  697775705.01893
#    quote.USD.volume_change_24h                                                 -18.53650
#    quote.USD.percent_change_1h                                                  -0.02721
#    quote.USD.percent_change_24h                                                 -0.11066
#    quote.USD.percent_change_7d                                                  -0.10025
#    quote.USD.percent_change_30d                                                 -0.03827
#    quote.USD.percent_change_60d                                                 -0.02871
#    quote.USD.percent_change_90d                                                 -0.14976
#    quote.USD.market_cap                                                 6833452966.48641
#    quote.USD.market_cap_dominance                                                0.69030
#    quote.USD.fully_diluted_market_cap                                   6833452966.49000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    platform.id                                                                1027.00000
#    platform.name                                                                Ethereum
#    platform.symbol                                                                   ETH
#    platform.slug                                                                ethereum
#    platform.token_address                     0x6b175474e89094c44da98b954eedeac495271d0f
#    timestamp                                                  2022-09-15 02:28:08.062603
# 13 id                                                                               5994
#    name                                                                        Shiba Inu
#    symbol                                                                           SHIB
#    slug                                                                        shiba-inu
#    num_market_pairs                                                                  413
#    date_added                                                   2020-08-01T00:00:00.000Z
#    tags                                    [memes, ethereum-ecosystem, doggone-doggerel]
#    circulating_supply                                              549063278876301.93750
#    total_supply                                                    589735030408322.75000
#    cmc_rank                                                                           14
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.00001
#    quote.USD.volume_24h                                                  311367632.30440
#    quote.USD.volume_change_24h                                                 -31.94350
#    quote.USD.percent_change_1h                                                  -0.53287
#    quote.USD.percent_change_24h                                                 -1.88842
#    quote.USD.percent_change_7d                                                  -1.64927
#    quote.USD.percent_change_30d                                                -22.74841
#    quote.USD.percent_change_60d                                                 10.30389
#    quote.USD.percent_change_90d                                                 47.27949
#    quote.USD.market_cap                                                 6620943027.27813
#    quote.USD.market_cap_dominance                                                0.66910
#    quote.USD.fully_diluted_market_cap                                   7111388045.32000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    platform.id                                                                1027.00000
#    platform.name                                                                Ethereum
#    platform.symbol                                                                   ETH
#    platform.slug                                                                ethereum
#    platform.token_address                     0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
#    timestamp                                                  2022-09-15 02:28:08.062603
# 14 id                                                                               1958
#    name                                                                             TRON
#    symbol                                                                            TRX
#    slug                                                                             tron
#    num_market_pairs                                                                  684
#    date_added                                                   2017-09-13T00:00:00.000Z
#    tags                                                [media, payments, tron-ecosystem]
#    circulating_supply                                                  92366671484.34125
#    total_supply                                                        92366665415.80617
#    cmc_rank                                                                           15
#    self_reported_circulating_supply                                    71659659264.00000
#    self_reported_market_cap                                             4373125246.45869
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.06103
#    quote.USD.volume_24h                                                  349859652.37644
#    quote.USD.volume_change_24h                                                 -13.99280
#    quote.USD.percent_change_1h                                                  -0.43845
#    quote.USD.percent_change_24h                                                 -0.29978
#    quote.USD.percent_change_7d                                                   0.50735
#    quote.USD.percent_change_30d                                                -11.43989
#    quote.USD.percent_change_60d                                                -11.03340
#    quote.USD.percent_change_90d                                                 -1.48665
#    quote.USD.market_cap                                                 5636797985.75951
#    quote.USD.market_cap_dominance                                                0.56850
#    quote.USD.fully_diluted_market_cap                                   5636797615.42000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 0  id                                                                                  1
#    name                                                                          Bitcoin
#    symbol                                                                            BTC
#    slug                                                                          bitcoin
#    num_market_pairs                                                                 9740
#    date_added                                                   2013-04-28T00:00:00.000Z
#    tags                                [mineable, pow, sha-256, store-of-value, state...
#    max_supply                                                             21000000.00000
#    circulating_supply                                                     19150881.00000
#    total_supply                                                           19150881.00000
#    cmc_rank                                                                            1
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                           20086.21755
#    quote.USD.volume_24h                                                37719571572.83210
#    quote.USD.volume_change_24h                                                 -26.45510
#    quote.USD.percent_change_1h                                                   0.03897
#    quote.USD.percent_change_24h                                                 -1.85478
#    quote.USD.percent_change_7d                                                   4.35521
#    quote.USD.percent_change_30d                                                -16.81022
#    quote.USD.percent_change_60d                                                 -5.14920
#    quote.USD.percent_change_90d                                                 -3.26165
#    quote.USD.market_cap                                               384668762102.85425
#    quote.USD.market_cap_dominance                                               38.89130
#    quote.USD.fully_diluted_market_cap                                 421810568618.75000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 1  id                                                                               1027
#    name                                                                         Ethereum
#    symbol                                                                            ETH
#    slug                                                                         ethereum
#    num_market_pairs                                                                 6089
#    date_added                                                   2015-08-07T00:00:00.000Z
#    tags                                [mineable, pow, smart-contracts, ethereum-ecos...
#    circulating_supply                                                    122371557.43650
#    total_supply                                                          122371557.43650
#    cmc_rank                                                                            2
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                            1611.22227
#    quote.USD.volume_24h                                                18789703865.52800
#    quote.USD.volume_change_24h                                                 -18.83000
#    quote.USD.percent_change_1h                                                  -0.09766
#    quote.USD.percent_change_24h                                                  1.02032
#    quote.USD.percent_change_7d                                                  -0.84751
#    quote.USD.percent_change_30d                                                -15.29056
#    quote.USD.percent_change_60d                                                 20.22622
#    quote.USD.percent_change_90d                                                 46.92122
#    quote.USD.market_cap                                               197167778257.05331
#    quote.USD.market_cap_dominance                                               19.92480
#    quote.USD.fully_diluted_market_cap                                 197167778257.04999
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 2  id                                                                                825
#    name                                                                           Tether
#    symbol                                                                           USDT
#    slug                                                                           tether
#    num_market_pairs                                                                39680
#    date_added                                                   2015-02-25T00:00:00.000Z
#    tags                                [payments, stablecoin, asset-backed-stablecoin...
#    circulating_supply                                                  67883438459.35066
#    total_supply                                                        69156782826.32211
#    cmc_rank                                                                            3
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               1.00014
#    quote.USD.volume_24h                                                55809535836.12127
#    quote.USD.volume_change_24h                                                 -22.10730
#    quote.USD.percent_change_1h                                                  -0.00447
#    quote.USD.percent_change_24h                                                  0.01103
#    quote.USD.percent_change_7d                                                   0.00254
#    quote.USD.percent_change_30d                                                 -0.00488
#    quote.USD.percent_change_60d                                                  0.03523
#    quote.USD.percent_change_90d                                                  0.12741
#    quote.USD.market_cap                                                67892702396.38782
#    quote.USD.market_cap_dominance                                                6.84760
#    quote.USD.fully_diluted_market_cap                                  69166220534.49001
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    platform.id                                                                1027.00000
#    platform.name                                                                Ethereum
#    platform.symbol                                                                   ETH
#    platform.slug                                                                ethereum
#    platform.token_address                     0xdac17f958d2ee523a2206206994597c13d831ec7
#    timestamp                                                  2022-09-15 02:28:08.062603
# 3  id                                                                               3408
#    name                                                                         USD Coin
#    symbol                                                                           USDC
#    slug                                                                         usd-coin
#    num_market_pairs                                                                 6195
#    date_added                                                   2018-10-08T00:00:00.000Z
#    tags                                [medium-of-exchange, stablecoin, asset-backed-...
#    circulating_supply                                                  50807456528.26229
#    total_supply                                                        50807456528.26229
#    cmc_rank                                                                            4
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.99999
#    quote.USD.volume_24h                                                 6034933916.62651
#    quote.USD.volume_change_24h                                                 -18.85240
#    quote.USD.percent_change_1h                                                  -0.00506
#    quote.USD.percent_change_24h                                                 -0.01695
#    quote.USD.percent_change_7d                                                  -0.01455
#    quote.USD.percent_change_30d                                                  0.00884
#    quote.USD.percent_change_60d                                                  0.01311
#    quote.USD.percent_change_90d                                                 -0.03083
#    quote.USD.market_cap                                                50807189090.23273
#    quote.USD.market_cap_dominance                                                5.13430
#    quote.USD.fully_diluted_market_cap                                  50807189090.23000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    platform.id                                                                1027.00000
#    platform.name                                                                Ethereum
#    platform.symbol                                                                   ETH
#    platform.slug                                                                ethereum
#    platform.token_address                     0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#    timestamp                                                  2022-09-15 02:28:08.062603
# 4  id                                                                               1839
#    name                                                                              BNB
#    symbol                                                                            BNB
#    slug                                                                              bnb
#    num_market_pairs                                                                 1103
#    date_added                                                   2017-07-25T00:00:00.000Z
#    tags                                [marketplace, centralized-exchange, payments, ...
#    max_supply                                                            200000000.00000
#    circulating_supply                                                    161337261.09000
#    total_supply                                                          161337261.09000
#    cmc_rank                                                                            5
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                             276.01300
#    quote.USD.volume_24h                                                  963370380.43727
#    quote.USD.volume_change_24h                                                 -15.13150
#    quote.USD.percent_change_1h                                                  -0.53336
#    quote.USD.percent_change_24h                                                 -1.28785
#    quote.USD.percent_change_7d                                                  -1.42330
# ...
#    quote.USD.price                                                              33.51488
#    quote.USD.volume_24h                                                  963134717.70034
#    quote.USD.volume_change_24h                                                 -45.62860
#    quote.USD.percent_change_1h                                                  -0.57820
#    quote.USD.percent_change_24h                                                 -0.36760
#    quote.USD.percent_change_7d                                                   3.11120
#    quote.USD.percent_change_30d                                                -23.26467
#    quote.USD.percent_change_60d                                                -15.13420
#    quote.USD.percent_change_90d                                                  9.35802
#    quote.USD.market_cap                                                11859180610.76805
#    quote.USD.market_cap_dominance                                                1.19610
#    quote.USD.fully_diluted_market_cap                                  17146778242.81000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 9  id                                                                                 74
#    name                                                                         Dogecoin
#    symbol                                                                           DOGE
#    slug                                                                         dogecoin
#    num_market_pairs                                                                  561
#    date_added                                                   2013-12-15T00:00:00.000Z
#    tags                                [mineable, pow, scrypt, medium-of-exchange, me...
#    circulating_supply                                                 132670764299.89409
#    total_supply                                                       132670764299.89409
#    cmc_rank                                                                           10
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.06035
#    quote.USD.volume_24h                                                  359048609.66663
#    quote.USD.volume_change_24h                                                 -21.94910
#    quote.USD.percent_change_1h                                                  -0.97646
#    quote.USD.percent_change_24h                                                 -0.00187
#    quote.USD.percent_change_7d                                                  -1.00299
#    quote.USD.percent_change_30d                                                -23.57526
#    quote.USD.percent_change_60d                                                 -5.70256
#    quote.USD.percent_change_90d                                                  7.16875
#    quote.USD.market_cap                                                 8007009368.49166
#    quote.USD.market_cap_dominance                                                0.80890
#    quote.USD.fully_diluted_market_cap                                   8007009368.49000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 10 id                                                                               6636
#    name                                                                         Polkadot
#    symbol                                                                            DOT
#    slug                                                                     polkadot-new
#    num_market_pairs                                                                  410
#    date_added                                                   2020-08-19T00:00:00.000Z
#    tags                                [substrate, polkadot, binance-chain, polkadot-...
#    circulating_supply                                                   1132527619.33446
#    total_supply                                                         1232557368.87714
#    cmc_rank                                                                           11
#    self_reported_circulating_supply                                      904869778.00000
#    self_reported_market_cap                                             6365447627.83482
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               7.03466
#    quote.USD.volume_24h                                                  321313192.91903
#    quote.USD.volume_change_24h                                                 -32.78130
#    quote.USD.percent_change_1h                                                  -0.88221
#    quote.USD.percent_change_24h                                                 -2.04595
#    quote.USD.percent_change_7d                                                  -2.40243
#    quote.USD.percent_change_30d                                                -20.13428
#    quote.USD.percent_change_60d                                                 -1.07761
#    quote.USD.percent_change_90d                                                 -3.28148
#    quote.USD.market_cap                                                 7966942231.05101
#    quote.USD.market_cap_dominance                                                0.80510
#    quote.USD.fully_diluted_market_cap                                   8670617110.49000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 11 id                                                                               3890
#    name                                                                          Polygon
#    symbol                                                                          MATIC
#    slug                                                                          polygon
#    num_market_pairs                                                                  484
#    date_added                                                   2019-04-28T00:00:00.000Z
#    tags                                [platform, enterprise-solutions, scaling, stat...
#    max_supply                                                          10000000000.00000
#    circulating_supply                                                   8734317475.28493
#    total_supply                                                        10000000000.00000
#    cmc_rank                                                                           12
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.84798
#    quote.USD.volume_24h                                                  405637500.02957
#    quote.USD.volume_change_24h                                                 -42.90480
#    quote.USD.percent_change_1h                                                  -0.50219
#    quote.USD.percent_change_24h                                                 -1.80370
#    quote.USD.percent_change_7d                                                   0.57742
#    quote.USD.percent_change_30d                                                -11.47706
#    quote.USD.percent_change_60d                                                 17.08748
#    quote.USD.percent_change_90d                                                116.70833
#    quote.USD.market_cap                                                 7406553454.09451
#    quote.USD.market_cap_dominance                                                0.74700
#    quote.USD.fully_diluted_market_cap                                   8479830822.56000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603
# 12 id                                                                               4943
#    name                                                                              Dai
#    symbol                                                                            DAI
#    slug                                                             multi-collateral-dai
#    num_market_pairs                                                                 1336
#    date_added                                                   2019-11-22T00:00:00.000Z
#    tags                                [defi, stablecoin, asset-backed-stablecoin, et...
#    circulating_supply                                                   6839924162.06719
#    total_supply                                                         6839924162.06719
#    cmc_rank                                                                           13
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.99905
#    quote.USD.volume_24h                                                  697775705.01893
#    quote.USD.volume_change_24h                                                 -18.53650
#    quote.USD.percent_change_1h                                                  -0.02721
#    quote.USD.percent_change_24h                                                 -0.11066
#    quote.USD.percent_change_7d                                                  -0.10025
#    quote.USD.percent_change_30d                                                 -0.03827
#    quote.USD.percent_change_60d                                                 -0.02871
#    quote.USD.percent_change_90d                                                 -0.14976
#    quote.USD.market_cap                                                 6833452966.48641
#    quote.USD.market_cap_dominance                                                0.69030
#    quote.USD.fully_diluted_market_cap                                   6833452966.49000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    platform.id                                                                1027.00000
#    platform.name                                                                Ethereum
#    platform.symbol                                                                   ETH
#    platform.slug                                                                ethereum
#    platform.token_address                     0x6b175474e89094c44da98b954eedeac495271d0f
#    timestamp                                                  2022-09-15 02:28:08.062603
# 13 id                                                                               5994
#    name                                                                        Shiba Inu
#    symbol                                                                           SHIB
#    slug                                                                        shiba-inu
#    num_market_pairs                                                                  413
#    date_added                                                   2020-08-01T00:00:00.000Z
#    tags                                    [memes, ethereum-ecosystem, doggone-doggerel]
#    circulating_supply                                              549063278876301.93750
#    total_supply                                                    589735030408322.75000
#    cmc_rank                                                                           14
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.00001
#    quote.USD.volume_24h                                                  311367632.30440
#    quote.USD.volume_change_24h                                                 -31.94350
#    quote.USD.percent_change_1h                                                  -0.53287
#    quote.USD.percent_change_24h                                                 -1.88842
#    quote.USD.percent_change_7d                                                  -1.64927
#    quote.USD.percent_change_30d                                                -22.74841
#    quote.USD.percent_change_60d                                                 10.30389
#    quote.USD.percent_change_90d                                                 47.27949
#    quote.USD.market_cap                                                 6620943027.27813
#    quote.USD.market_cap_dominance                                                0.66910
#    quote.USD.fully_diluted_market_cap                                   7111388045.32000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    platform.id                                                                1027.00000
#    platform.name                                                                Ethereum
#    platform.symbol                                                                   ETH
#    platform.slug                                                                ethereum
#    platform.token_address                     0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
#    timestamp                                                  2022-09-15 02:28:08.062603
# 14 id                                                                               1958
#    name                                                                             TRON
#    symbol                                                                            TRX
#    slug                                                                             tron
#    num_market_pairs                                                                  684
#    date_added                                                   2017-09-13T00:00:00.000Z
#    tags                                                [media, payments, tron-ecosystem]
#    circulating_supply                                                  92366671484.34125
#    total_supply                                                        92366665415.80617
#    cmc_rank                                                                           15
#    self_reported_circulating_supply                                    71659659264.00000
#    self_reported_market_cap                                             4373125246.45869
#    last_updated                                                 2022-09-15T02:26:00.000Z
#    quote.USD.price                                                               0.06103
#    quote.USD.volume_24h                                                  349859652.37644
#    quote.USD.volume_change_24h                                                 -13.99280
#    quote.USD.percent_change_1h                                                  -0.43845
#    quote.USD.percent_change_24h                                                 -0.29978
#    quote.USD.percent_change_7d                                                   0.50735
#    quote.USD.percent_change_30d                                                -11.43989
#    quote.USD.percent_change_60d                                                -11.03340
#    quote.USD.percent_change_90d                                                 -1.48665
#    quote.USD.market_cap                                                 5636797985.75951
#    quote.USD.market_cap_dominance                                                0.56850
#    quote.USD.fully_diluted_market_cap                                   5636797615.42000
#    quote.USD.last_updated                                       2022-09-15T02:26:00.000Z
#    timestamp                                                  2022-09-15 02:28:08.062603

# %%
df3.count()
# Out:
# name    818
# dtype: int64

# %%
index = pd.Index(range(818))


df4 = df3.reset_index()
df4
# Out:
#      level_0                             level_1  \
# 0          0                                  id
# 1          0                                name
# 2          0                              symbol
# 3          0                                slug
# 4          0                    num_market_pairs
# 5          0                          date_added
# 6          0                                tags
# 7          0                          max_supply
# 8          0                  circulating_supply
# 9          0                        total_supply
# 10         0                            cmc_rank
# 11         0                        last_updated
# 12         0                     quote.USD.price
# 13         0                quote.USD.volume_24h
# 14         0         quote.USD.volume_change_24h
# 15         0         quote.USD.percent_change_1h
# 16         0        quote.USD.percent_change_24h
# 17         0         quote.USD.percent_change_7d
# 18         0        quote.USD.percent_change_30d
# 19         0        quote.USD.percent_change_60d
# 20         0        quote.USD.percent_change_90d
# 21         0                quote.USD.market_cap
# 22         0      quote.USD.market_cap_dominance
# 23         0  quote.USD.fully_diluted_market_cap
# 24         0              quote.USD.last_updated
# 25         0                           timestamp
# 26         1                                  id
# 27         1                                name
# 28         1                              symbol
# 29         1                                slug
# 30         1                    num_market_pairs
# 31         1                          date_added
# 32         1                                tags
# 33         1                  circulating_supply
# 34         1                        total_supply
# 35         1                            cmc_rank
# 36         1                        last_updated
# 37         1                     quote.USD.price
# 38         1                quote.USD.volume_24h
# 39         1         quote.USD.volume_change_24h
# 40         1         quote.USD.percent_change_1h
# 41         1        quote.USD.percent_change_24h
# 42         1         quote.USD.percent_change_7d
# 43         1        quote.USD.percent_change_30d
# 44         1        quote.USD.percent_change_60d
# 45         1        quote.USD.percent_change_90d
# 46         1                quote.USD.market_cap
# 47         1      quote.USD.market_cap_dominance
# 48         1  quote.USD.fully_diluted_market_cap
# 49         1              quote.USD.last_updated
# 50         1                           timestamp
# 51         2                                  id
# 52         2                                name
# 53         2                              symbol
# 54         2                                slug
# 55         2                    num_market_pairs
# 56         2                          date_added
# 57         2                                tags
# 58         2                  circulating_supply
# 59         2                        total_supply
# 60         2                            cmc_rank
# 61         2                        last_updated
# 62         2                     quote.USD.price
# 63         2                quote.USD.volume_24h
# 64         2         quote.USD.volume_change_24h
# 65         2         quote.USD.percent_change_1h
# 66         2        quote.USD.percent_change_24h
# 67         2         quote.USD.percent_change_7d
# 68         2        quote.USD.percent_change_30d
# 69         2        quote.USD.percent_change_60d
# 70         2        quote.USD.percent_change_90d
# 71         2                quote.USD.market_cap
# 72         2      quote.USD.market_cap_dominance
# 73         2  quote.USD.fully_diluted_market_cap
# 74         2              quote.USD.last_updated
# 75         2                         platform.id
# 76         2                       platform.name
# 77         2                     platform.symbol
# 78         2                       platform.slug
# 79         2              platform.token_address
# 80         2                           timestamp
# 81         3                                  id
# 82         3                                name
# 83         3                              symbol
# 84         3                                slug
# 85         3                    num_market_pairs
# 86         3                          date_added
# 87         3                                tags
# 88         3                  circulating_supply
# 89         3                        total_supply
# 90         3                            cmc_rank
# 91         3                        last_updated
# 92         3                     quote.USD.price
# 93         3                quote.USD.volume_24h
# 94         3         quote.USD.volume_change_24h
# 95         3         quote.USD.percent_change_1h
# 96         3        quote.USD.percent_change_24h
# 97         3         quote.USD.percent_change_7d
# 98         3        quote.USD.percent_change_30d
# 99         3        quote.USD.percent_change_60d
# 100        3        quote.USD.percent_change_90d
# 101        3                quote.USD.market_cap
# 102        3      quote.USD.market_cap_dominance
# 103        3  quote.USD.fully_diluted_market_cap
# 104        3              quote.USD.last_updated
# 105        3                         platform.id
# 106        3                       platform.name
# 107        3                     platform.symbol
# 108        3                       platform.slug
# 109        3              platform.token_address
# 110        3                           timestamp
# 111        4                                  id
# 112        4                                name
# 113        4                              symbol
# 114        4                                slug
# 115        4                    num_market_pairs
# 116        4                          date_added
# 117        4                                tags
# 118        4                          max_supply
# 119        4                  circulating_supply
# 120        4                        total_supply
# 121        4                            cmc_rank
# 122        4                        last_updated
# 123        4                     quote.USD.price
# 124        4                quote.USD.volume_24h
# 125        4         quote.USD.volume_change_24h
# 126        4         quote.USD.percent_change_1h
# 127        4        quote.USD.percent_change_24h
# 128        4         quote.USD.percent_change_7d
# 129        4        quote.USD.percent_change_30d
# 130        4        quote.USD.percent_change_60d
# 131        4        quote.USD.percent_change_90d
# 132        4                quote.USD.market_cap
# 133        4      quote.USD.market_cap_dominance
# 134        4  quote.USD.fully_diluted_market_cap
# 135        4              quote.USD.last_updated
# 136        4                           timestamp
# 137        5                                  id
# 138        5                                name
# 139        5                              symbol
# 140        5                                slug
# 141        5                    num_market_pairs
# 142        5                          date_added
# 143        5                                tags
# 144        5                  circulating_supply
# 145        5                        total_supply
# 146        5                            cmc_rank
# 147        5                        last_updated
# 148        5                     quote.USD.price
# 149        5                quote.USD.volume_24h
# 150        5         quote.USD.volume_change_24h
# 151        5         quote.USD.percent_change_1h
# 152        5        quote.USD.percent_change_24h
# 153        5         quote.USD.percent_change_7d
# 154        5        quote.USD.percent_change_30d
# 155        5        quote.USD.percent_change_60d
# 156        5        quote.USD.percent_change_90d
# 157        5                quote.USD.market_cap
# 158        5      quote.USD.market_cap_dominance
# 159        5  quote.USD.fully_diluted_market_cap
# 160        5              quote.USD.last_updated
# 161        5                         platform.id
# 162        5                       platform.name
# 163        5                     platform.symbol
# 164        5                       platform.slug
# 165        5              platform.token_address
# 166        5                           timestamp
# 167        6                                  id
# 168        6                                name
# 169        6                              symbol
# 170        6                                slug
# 171        6                    num_market_pairs
# 172        6                          date_added
# 173        6                                tags
# 174        6                          max_supply
# 175        6                  circulating_supply
# 176        6                        total_supply
# 177        6                            cmc_rank
# 178        6                        last_updated
# 179        6                     quote.USD.price
# 180        6                quote.USD.volume_24h
# 181        6         quote.USD.volume_change_24h
# 182        6         quote.USD.percent_change_1h
# 183        6        quote.USD.percent_change_24h
# 184        6         quote.USD.percent_change_7d
# 185        6        quote.USD.percent_change_30d
# 186        6        quote.USD.percent_change_60d
# 187        6        quote.USD.percent_change_90d
# 188        6                quote.USD.market_cap
# 189        6      quote.USD.market_cap_dominance
# 190        6  quote.USD.fully_diluted_market_cap
# 191        6              quote.USD.last_updated
# 192        6                           timestamp
# 193        7                                  id
# 194        7                                name
# 195        7                              symbol
# 196        7                                slug
# 197        7                    num_market_pairs
# 198        7                          date_added
# 199        7                                tags
# 200        7                          max_supply
# 201        7                  circulating_supply
# 202        7                        total_supply
# 203        7                            cmc_rank
# 204        7                        last_updated
# 205        7                     quote.USD.price
# 206        7                quote.USD.volume_24h
# 207        7         quote.USD.volume_change_24h
# 208        7         quote.USD.percent_change_1h
# 209        7        quote.USD.percent_change_24h
# 210        7         quote.USD.percent_change_7d
# 211        7        quote.USD.percent_change_30d
# 212        7        quote.USD.percent_change_60d
# 213        7        quote.USD.percent_change_90d
# 214        7                quote.USD.market_cap
# 215        7      quote.USD.market_cap_dominance
# 216        7  quote.USD.fully_diluted_market_cap
# 217        7              quote.USD.last_updated
# 218        7                           timestamp
# 219        8                                  id
# 220        8                                name
# 221        8                              symbol
# 222        8                                slug
# 223        8                    num_market_pairs
# 224        8                          date_added
# 225        8                                tags
# 226        8                  circulating_supply
# 227        8                        total_supply
# 228        8                            cmc_rank
# 229        8                        last_updated
# 230        8                     quote.USD.price
# 231        8                quote.USD.volume_24h
# 232        8         quote.USD.volume_change_24h
# 233        8         quote.USD.percent_change_1h
# 234        8        quote.USD.percent_change_24h
# 235        8         quote.USD.percent_change_7d
# 236        8        quote.USD.percent_change_30d
# 237        8        quote.USD.percent_change_60d
# 238        8        quote.USD.percent_change_90d
# 239        8                quote.USD.market_cap
# 240        8      quote.USD.market_cap_dominance
# 241        8  quote.USD.fully_diluted_market_cap
# 242        8              quote.USD.last_updated
# 243        8                           timestamp
# 244        9                                  id
# 245        9                                name
# 246        9                              symbol
# 247        9                                slug
# 248        9                    num_market_pairs
# 249        9                          date_added
# 250        9                                tags
# 251        9                  circulating_supply
# 252        9                        total_supply
# 253        9                            cmc_rank
# 254        9                        last_updated
# 255        9                     quote.USD.price
# 256        9                quote.USD.volume_24h
# 257        9         quote.USD.volume_change_24h
# 258        9         quote.USD.percent_change_1h
# 259        9        quote.USD.percent_change_24h
# 260        9         quote.USD.percent_change_7d
# 261        9        quote.USD.percent_change_30d
# 262        9        quote.USD.percent_change_60d
# 263        9        quote.USD.percent_change_90d
# 264        9                quote.USD.market_cap
# 265        9      quote.USD.market_cap_dominance
# 266        9  quote.USD.fully_diluted_market_cap
# 267        9              quote.USD.last_updated
# 268        9                           timestamp
# 269       10                                  id
# 270       10                                name
# 271       10                              symbol
# 272       10                                slug
# 273       10                    num_market_pairs
# 274       10                          date_added
# 275       10                                tags
# 276       10                  circulating_supply
# 277       10                        total_supply
# 278       10                            cmc_rank
# 279       10    self_reported_circulating_supply
# 280       10            self_reported_market_cap
# 281       10                        last_updated
# 282       10                     quote.USD.price
# 283       10                quote.USD.volume_24h
# 284       10         quote.USD.volume_change_24h
# 285       10         quote.USD.percent_change_1h
# 286       10        quote.USD.percent_change_24h
# 287       10         quote.USD.percent_change_7d
# 288       10        quote.USD.percent_change_30d
# 289       10        quote.USD.percent_change_60d
# 290       10        quote.USD.percent_change_90d
# 291       10                quote.USD.market_cap
# 292       10      quote.USD.market_cap_dominance
# 293       10  quote.USD.fully_diluted_market_cap
# 294       10              quote.USD.last_updated
# 295       10                           timestamp
# 296       11                                  id
# 297       11                                name
# 298       11                              symbol
# 299       11                                slug
# 300       11                    num_market_pairs
# 301       11                          date_added
# 302       11                                tags
# 303       11                          max_supply
# 304       11                  circulating_supply
# 305       11                        total_supply
# 306       11                            cmc_rank
# 307       11                        last_updated
# 308       11                     quote.USD.price
# 309       11                quote.USD.volume_24h
# 310       11         quote.USD.volume_change_24h
# 311       11         quote.USD.percent_change_1h
# 312       11        quote.USD.percent_change_24h
# 313       11         quote.USD.percent_change_7d
# 314       11        quote.USD.percent_change_30d
# 315       11        quote.USD.percent_change_60d
# 316       11        quote.USD.percent_change_90d
# 317       11                quote.USD.market_cap
# 318       11      quote.USD.market_cap_dominance
# 319       11  quote.USD.fully_diluted_market_cap
# 320       11              quote.USD.last_updated
# 321       11                           timestamp
# 322       12                                  id
# 323       12                                name
# 324       12                              symbol
# 325       12                                slug
# 326       12                    num_market_pairs
# 327       12                          date_added
# 328       12                                tags
# 329       12                  circulating_supply
# 330       12                        total_supply
# 331       12                            cmc_rank
# 332       12                        last_updated
# 333       12                     quote.USD.price
# 334       12                quote.USD.volume_24h
# 335       12         quote.USD.volume_change_24h
# 336       12         quote.USD.percent_change_1h
# 337       12        quote.USD.percent_change_24h
# 338       12         quote.USD.percent_change_7d
# 339       12        quote.USD.percent_change_30d
# 340       12        quote.USD.percent_change_60d
# 341       12        quote.USD.percent_change_90d
# 342       12                quote.USD.market_cap
# 343       12      quote.USD.market_cap_dominance
# 344       12  quote.USD.fully_diluted_market_cap
# 345       12              quote.USD.last_updated
# 346       12                         platform.id
# 347       12                       platform.name
# 348       12                     platform.symbol
# 349       12                       platform.slug
# 350       12              platform.token_address
# 351       12                           timestamp
# 352       13                                  id
# 353       13                                name
# 354       13                              symbol
# 355       13                                slug
# 356       13                    num_market_pairs
# 357       13                          date_added
# 358       13                                tags
# 359       13                  circulating_supply
# 360       13                        total_supply
# 361       13                            cmc_rank
# 362       13                        last_updated
# 363       13                     quote.USD.price
# 364       13                quote.USD.volume_24h
# 365       13         quote.USD.volume_change_24h
# 366       13         quote.USD.percent_change_1h
# 367       13        quote.USD.percent_change_24h
# 368       13         quote.USD.percent_change_7d
# 369       13        quote.USD.percent_change_30d
# 370       13        quote.USD.percent_change_60d
# 371       13        quote.USD.percent_change_90d
# 372       13                quote.USD.market_cap
# 373       13      quote.USD.market_cap_dominance
# 374       13  quote.USD.fully_diluted_market_cap
# 375       13              quote.USD.last_updated
# 376       13                         platform.id
# 377       13                       platform.name
# 378       13                     platform.symbol
# 379       13                       platform.slug
# 380       13              platform.token_address
# 381       13                           timestamp
# 382       14                                  id
# 383       14                                name
# 384       14                              symbol
# 385       14                                slug
# 386       14                    num_market_pairs
# 387       14                          date_added
# 388       14                                tags
# 389       14                  circulating_supply
# 390       14                        total_supply
# 391       14                            cmc_rank
# 392       14    self_reported_circulating_supply
# 393       14            self_reported_market_cap
# 394       14                        last_updated
# 395       14                     quote.USD.price
# 396       14                quote.USD.volume_24h
# 397       14         quote.USD.volume_change_24h
# 398       14         quote.USD.percent_change_1h
# 399       14        quote.USD.percent_change_24h
# 400       14         quote.USD.percent_change_7d
# 401       14        quote.USD.percent_change_30d
# 402       14        quote.USD.percent_change_60d
# 403       14        quote.USD.percent_change_90d
# 404       14                quote.USD.market_cap
# 405       14      quote.USD.market_cap_dominance
# 406       14  quote.USD.fully_diluted_market_cap
# 407       14              quote.USD.last_updated
# 408       14                           timestamp
# 409        0                                  id
# 410        0                                name
# 411        0                              symbol
# 412        0                                slug
# 413        0                    num_market_pairs
# 414        0                          date_added
# 415        0                                tags
# 416        0                          max_supply
# 417        0                  circulating_supply
# 418        0                        total_supply
# 419        0                            cmc_rank
# 420        0                        last_updated
# 421        0                     quote.USD.price
# 422        0                quote.USD.volume_24h
# 423        0         quote.USD.volume_change_24h
# 424        0         quote.USD.percent_change_1h
# 425        0        quote.USD.percent_change_24h
# 426        0         quote.USD.percent_change_7d
# 427        0        quote.USD.percent_change_30d
# 428        0        quote.USD.percent_change_60d
# 429        0        quote.USD.percent_change_90d
# 430        0                quote.USD.market_cap
# 431        0      quote.USD.market_cap_dominance
# 432        0  quote.USD.fully_diluted_market_cap
# 433        0              quote.USD.last_updated
# 434        0                           timestamp
# 435        1                                  id
# 436        1                                name
# 437        1                              symbol
# 438        1                                slug
# 439        1                    num_market_pairs
# 440        1                          date_added
# 441        1                                tags
# 442        1                  circulating_supply
# 443        1                        total_supply
# 444        1                            cmc_rank
# 445        1                        last_updated
# 446        1                     quote.USD.price
# 447        1                quote.USD.volume_24h
# 448        1         quote.USD.volume_change_24h
# 449        1         quote.USD.percent_change_1h
# 450        1        quote.USD.percent_change_24h
# 451        1         quote.USD.percent_change_7d
# 452        1        quote.USD.percent_change_30d
# 453        1        quote.USD.percent_change_60d
# 454        1        quote.USD.percent_change_90d
# 455        1                quote.USD.market_cap
# 456        1      quote.USD.market_cap_dominance
# 457        1  quote.USD.fully_diluted_market_cap
# 458        1              quote.USD.last_updated
# 459        1                           timestamp
# 460        2                                  id
# 461        2                                name
# 462        2                              symbol
# 463        2                                slug
# 464        2                    num_market_pairs
# 465        2                          date_added
# 466        2                                tags
# 467        2                  circulating_supply
# 468        2                        total_supply
# 469        2                            cmc_rank
# 470        2                        last_updated
# 471        2                     quote.USD.price
# 472        2                quote.USD.volume_24h
# 473        2         quote.USD.volume_change_24h
# 474        2         quote.USD.percent_change_1h
# 475        2        quote.USD.percent_change_24h
# 476        2         quote.USD.percent_change_7d
# 477        2        quote.USD.percent_change_30d
# 478        2        quote.USD.percent_change_60d
# 479        2        quote.USD.percent_change_90d
# 480        2                quote.USD.market_cap
# 481        2      quote.USD.market_cap_dominance
# 482        2  quote.USD.fully_diluted_market_cap
# 483        2              quote.USD.last_updated
# 484        2                         platform.id
# 485        2                       platform.name
# 486        2                     platform.symbol
# 487        2                       platform.slug
# 488        2              platform.token_address
# 489        2                           timestamp
# 490        3                                  id
# 491        3                                name
# 492        3                              symbol
# 493        3                                slug
# 494        3                    num_market_pairs
# 495        3                          date_added
# 496        3                                tags
# 497        3                  circulating_supply
# 498        3                        total_supply
# 499        3                            cmc_rank
# 500        3                        last_updated
# 501        3                     quote.USD.price
# 502        3                quote.USD.volume_24h
# 503        3         quote.USD.volume_change_24h
# 504        3         quote.USD.percent_change_1h
# 505        3        quote.USD.percent_change_24h
# 506        3         quote.USD.percent_change_7d
# 507        3        quote.USD.percent_change_30d
# 508        3        quote.USD.percent_change_60d
# 509        3        quote.USD.percent_change_90d
# 510        3                quote.USD.market_cap
# 511        3      quote.USD.market_cap_dominance
# 512        3  quote.USD.fully_diluted_market_cap
# 513        3              quote.USD.last_updated
# 514        3                         platform.id
# 515        3                       platform.name
# 516        3                     platform.symbol
# 517        3                       platform.slug
# 518        3              platform.token_address
# 519        3                           timestamp
# 520        4                                  id
# 521        4                                name
# 522        4                              symbol
# 523        4                                slug
# 524        4                    num_market_pairs
# 525        4                          date_added
# 526        4                                tags
# 527        4                          max_supply
# 528        4                  circulating_supply
# 529        4                        total_supply
# 530        4                            cmc_rank
# 531        4                        last_updated
# 532        4                     quote.USD.price
# 533        4                quote.USD.volume_24h
# 534        4         quote.USD.volume_change_24h
# 535        4         quote.USD.percent_change_1h
# 536        4        quote.USD.percent_change_24h
# 537        4         quote.USD.percent_change_7d
# 538        4        quote.USD.percent_change_30d
# 539        4        quote.USD.percent_change_60d
# 540        4        quote.USD.percent_change_90d
# 541        4                quote.USD.market_cap
# 542        4      quote.USD.market_cap_dominance
# 543        4  quote.USD.fully_diluted_market_cap
# 544        4              quote.USD.last_updated
# 545        4                           timestamp
# 546        5                                  id
# 547        5                                name
# 548        5                              symbol
# 549        5                                slug
# 550        5                    num_market_pairs
# 551        5                          date_added
# 552        5                                tags
# 553        5                  circulating_supply
# 554        5                        total_supply
# 555        5                            cmc_rank
# 556        5                        last_updated
# 557        5                     quote.USD.price
# 558        5                quote.USD.volume_24h
# 559        5         quote.USD.volume_change_24h
# 560        5         quote.USD.percent_change_1h
# 561        5        quote.USD.percent_change_24h
# 562        5         quote.USD.percent_change_7d
# 563        5        quote.USD.percent_change_30d
# 564        5        quote.USD.percent_change_60d
# 565        5        quote.USD.percent_change_90d
# 566        5                quote.USD.market_cap
# 567        5      quote.USD.market_cap_dominance
# 568        5  quote.USD.fully_diluted_market_cap
# 569        5              quote.USD.last_updated
# 570        5                         platform.id
# 571        5                       platform.name
# 572        5                     platform.symbol
# 573        5                       platform.slug
# 574        5              platform.token_address
# 575        5                           timestamp
# 576        6                                  id
# 577        6                                name
# 578        6                              symbol
# 579        6                                slug
# 580        6                    num_market_pairs
# 581        6                          date_added
# 582        6                                tags
# 583        6                          max_supply
# 584        6                  circulating_supply
# 585        6                        total_supply
# 586        6                            cmc_rank
# 587        6                        last_updated
# 588        6                     quote.USD.price
# 589        6                quote.USD.volume_24h
# 590        6         quote.USD.volume_change_24h
# 591        6         quote.USD.percent_change_1h
# 592        6        quote.USD.percent_change_24h
# 593        6         quote.USD.percent_change_7d
# 594        6        quote.USD.percent_change_30d
# 595        6        quote.USD.percent_change_60d
# 596        6        quote.USD.percent_change_90d
# 597        6                quote.USD.market_cap
# 598        6      quote.USD.market_cap_dominance
# 599        6  quote.USD.fully_diluted_market_cap
# 600        6              quote.USD.last_updated
# 601        6                           timestamp
# 602        7                                  id
# 603        7                                name
# 604        7                              symbol
# 605        7                                slug
# 606        7                    num_market_pairs
# 607        7                          date_added
# 608        7                                tags
# 609        7                          max_supply
# 610        7                  circulating_supply
# 611        7                        total_supply
# 612        7                            cmc_rank
# 613        7                        last_updated
# 614        7                     quote.USD.price
# 615        7                quote.USD.volume_24h
# 616        7         quote.USD.volume_change_24h
# 617        7         quote.USD.percent_change_1h
# 618        7        quote.USD.percent_change_24h
# 619        7         quote.USD.percent_change_7d
# 620        7        quote.USD.percent_change_30d
# 621        7        quote.USD.percent_change_60d
# 622        7        quote.USD.percent_change_90d
# 623        7                quote.USD.market_cap
# 624        7      quote.USD.market_cap_dominance
# 625        7  quote.USD.fully_diluted_market_cap
# 626        7              quote.USD.last_updated
# 627        7                           timestamp
# 628        8                                  id
# 629        8                                name
# 630        8                              symbol
# 631        8                                slug
# 632        8                    num_market_pairs
# 633        8                          date_added
# 634        8                                tags
# 635        8                  circulating_supply
# 636        8                        total_supply
# 637        8                            cmc_rank
# 638        8                        last_updated
# 639        8                     quote.USD.price
# 640        8                quote.USD.volume_24h
# 641        8         quote.USD.volume_change_24h
# 642        8         quote.USD.percent_change_1h
# 643        8        quote.USD.percent_change_24h
# 644        8         quote.USD.percent_change_7d
# 645        8        quote.USD.percent_change_30d
# 646        8        quote.USD.percent_change_60d
# 647        8        quote.USD.percent_change_90d
# 648        8                quote.USD.market_cap
# 649        8      quote.USD.market_cap_dominance
# 650        8  quote.USD.fully_diluted_market_cap
# 651        8              quote.USD.last_updated
# 652        8                           timestamp
# 653        9                                  id
# 654        9                                name
# 655        9                              symbol
# 656        9                                slug
# 657        9                    num_market_pairs
# 658        9                          date_added
# 659        9                                tags
# 660        9                  circulating_supply
# 661        9                        total_supply
# 662        9                            cmc_rank
# 663        9                        last_updated
# 664        9                     quote.USD.price
# 665        9                quote.USD.volume_24h
# 666        9         quote.USD.volume_change_24h
# 667        9         quote.USD.percent_change_1h
# 668        9        quote.USD.percent_change_24h
# 669        9         quote.USD.percent_change_7d
# 670        9        quote.USD.percent_change_30d
# 671        9        quote.USD.percent_change_60d
# 672        9        quote.USD.percent_change_90d
# 673        9                quote.USD.market_cap
# 674        9      quote.USD.market_cap_dominance
# 675        9  quote.USD.fully_diluted_market_cap
# 676        9              quote.USD.last_updated
# 677        9                           timestamp
# 678       10                                  id
# 679       10                                name
# 680       10                              symbol
# 681       10                                slug
# 682       10                    num_market_pairs
# 683       10                          date_added
# 684       10                                tags
# 685       10                  circulating_supply
# 686       10                        total_supply
# 687       10                            cmc_rank
# 688       10    self_reported_circulating_supply
# 689       10            self_reported_market_cap
# 690       10                        last_updated
# 691       10                     quote.USD.price
# 692       10                quote.USD.volume_24h
# 693       10         quote.USD.volume_change_24h
# 694       10         quote.USD.percent_change_1h
# 695       10        quote.USD.percent_change_24h
# 696       10         quote.USD.percent_change_7d
# 697       10        quote.USD.percent_change_30d
# 698       10        quote.USD.percent_change_60d
# 699       10        quote.USD.percent_change_90d
# 700       10                quote.USD.market_cap
# 701       10      quote.USD.market_cap_dominance
# 702       10  quote.USD.fully_diluted_market_cap
# 703       10              quote.USD.last_updated
# 704       10                           timestamp
# 705       11                                  id
# 706       11                                name
# 707       11                              symbol
# 708       11                                slug
# 709       11                    num_market_pairs
# 710       11                          date_added
# 711       11                                tags
# 712       11                          max_supply
# 713       11                  circulating_supply
# 714       11                        total_supply
# 715       11                            cmc_rank
# 716       11                        last_updated
# 717       11                     quote.USD.price
# 718       11                quote.USD.volume_24h
# 719       11         quote.USD.volume_change_24h
# 720       11         quote.USD.percent_change_1h
# 721       11        quote.USD.percent_change_24h
# 722       11         quote.USD.percent_change_7d
# 723       11        quote.USD.percent_change_30d
# 724       11        quote.USD.percent_change_60d
# 725       11        quote.USD.percent_change_90d
# 726       11                quote.USD.market_cap
# 727       11      quote.USD.market_cap_dominance
# 728       11  quote.USD.fully_diluted_market_cap
# 729       11              quote.USD.last_updated
# 730       11                           timestamp
# 731       12                                  id
# 732       12                                name
# 733       12                              symbol
# 734       12                                slug
# 735       12                    num_market_pairs
# 736       12                          date_added
# 737       12                                tags
# 738       12                  circulating_supply
# 739       12                        total_supply
# 740       12                            cmc_rank
# 741       12                        last_updated
# 742       12                     quote.USD.price
# 743       12                quote.USD.volume_24h
# 744       12         quote.USD.volume_change_24h
# 745       12         quote.USD.percent_change_1h
# 746       12        quote.USD.percent_change_24h
# 747       12         quote.USD.percent_change_7d
# 748       12        quote.USD.percent_change_30d
# 749       12        quote.USD.percent_change_60d
# 750       12        quote.USD.percent_change_90d
# 751       12                quote.USD.market_cap
# 752       12      quote.USD.market_cap_dominance
# 753       12  quote.USD.fully_diluted_market_cap
# 754       12              quote.USD.last_updated
# 755       12                         platform.id
# 756       12                       platform.name
# 757       12                     platform.symbol
# 758       12                       platform.slug
# 759       12              platform.token_address
# 760       12                           timestamp
# 761       13                                  id
# 762       13                                name
# 763       13                              symbol
# 764       13                                slug
# 765       13                    num_market_pairs
# 766       13                          date_added
# 767       13                                tags
# 768       13                  circulating_supply
# 769       13                        total_supply
# 770       13                            cmc_rank
# 771       13                        last_updated
# 772       13                     quote.USD.price
# 773       13                quote.USD.volume_24h
# 774       13         quote.USD.volume_change_24h
# 775       13         quote.USD.percent_change_1h
# 776       13        quote.USD.percent_change_24h
# 777       13         quote.USD.percent_change_7d
# 778       13        quote.USD.percent_change_30d
# 779       13        quote.USD.percent_change_60d
# 780       13        quote.USD.percent_change_90d
# 781       13                quote.USD.market_cap
# 782       13      quote.USD.market_cap_dominance
# 783       13  quote.USD.fully_diluted_market_cap
# 784       13              quote.USD.last_updated
# 785       13                         platform.id
# 786       13                       platform.name
# 787       13                     platform.symbol
# 788       13                       platform.slug
# 789       13              platform.token_address
# 790       13                           timestamp
# 791       14                                  id
# 792       14                                name
# 793       14                              symbol
# 794       14                                slug
# 795       14                    num_market_pairs
# 796       14                          date_added
# 797       14                                tags
# 798       14                  circulating_supply
# 799       14                        total_supply
# 800       14                            cmc_rank
# 801       14    self_reported_circulating_supply
# 802       14            self_reported_market_cap
# 803       14                        last_updated
# 804       14                     quote.USD.price
# 805       14                quote.USD.volume_24h
# 806       14         quote.USD.volume_change_24h
# 807       14         quote.USD.percent_change_1h
# 808       14        quote.USD.percent_change_24h
# 809       14         quote.USD.percent_change_7d
# 810       14        quote.USD.percent_change_30d
# 811       14        quote.USD.percent_change_60d
# 812       14        quote.USD.percent_change_90d
# 813       14                quote.USD.market_cap
# 814       14      quote.USD.market_cap_dominance
# 815       14  quote.USD.fully_diluted_market_cap
# 816       14              quote.USD.last_updated
# 817       14                           timestamp
#
#                                                   name
# 0                                                    1
# 1                                              Bitcoin
# 2                                                  BTC
# 3                                              bitcoin
# 4                                                 9740
# 5                             2013-04-28T00:00:00.000Z
# 6    [mineable, pow, sha-256, store-of-value, state...
# 7                                       21000000.00000
# 8                                       19150881.00000
# 9                                       19150881.00000
# 10                                                   1
# 11                            2022-09-15T02:26:00.000Z
# 12                                         20086.21755
# 13                                   37719571572.83210
# 14                                           -26.45510
# 15                                             0.03897
# 16                                            -1.85478
# 17                                             4.35521
# 18                                           -16.81022
# 19                                            -5.14920
# 20                                            -3.26165
# 21                                  384668762102.85425
# 22                                            38.89130
# 23                                  421810568618.75000
# 24                            2022-09-15T02:26:00.000Z
# 25                          2022-09-15 02:28:08.062603
# 26                                                1027
# 27                                            Ethereum
# 28                                                 ETH
# 29                                            ethereum
# 30                                                6089
# 31                            2015-08-07T00:00:00.000Z
# 32   [mineable, pow, smart-contracts, ethereum-ecos...
# 33                                     122371557.43650
# 34                                     122371557.43650
# 35                                                   2
# 36                            2022-09-15T02:26:00.000Z
# 37                                          1611.22227
# 38                                   18789703865.52800
# 39                                           -18.83000
# 40                                            -0.09766
# 41                                             1.02032
# 42                                            -0.84751
# 43                                           -15.29056
# 44                                            20.22622
# 45                                            46.92122
# 46                                  197167778257.05331
# 47                                            19.92480
# 48                                  197167778257.04999
# 49                            2022-09-15T02:26:00.000Z
# 50                          2022-09-15 02:28:08.062603
# 51                                                 825
# 52                                              Tether
# 53                                                USDT
# 54                                              tether
# 55                                               39680
# 56                            2015-02-25T00:00:00.000Z
# 57   [payments, stablecoin, asset-backed-stablecoin...
# 58                                   67883438459.35066
# 59                                   69156782826.32211
# 60                                                   3
# 61                            2022-09-15T02:26:00.000Z
# 62                                             1.00014
# 63                                   55809535836.12127
# 64                                           -22.10730
# 65                                            -0.00447
# 66                                             0.01103
# 67                                             0.00254
# 68                                            -0.00488
# 69                                             0.03523
# 70                                             0.12741
# 71                                   67892702396.38782
# 72                                             6.84760
# 73                                   69166220534.49001
# 74                            2022-09-15T02:26:00.000Z
# 75                                          1027.00000
# 76                                            Ethereum
# 77                                                 ETH
# 78                                            ethereum
# 79          0xdac17f958d2ee523a2206206994597c13d831ec7
# 80                          2022-09-15 02:28:08.062603
# 81                                                3408
# 82                                            USD Coin
# 83                                                USDC
# 84                                            usd-coin
# 85                                                6195
# 86                            2018-10-08T00:00:00.000Z
# 87   [medium-of-exchange, stablecoin, asset-backed-...
# 88                                   50807456528.26229
# 89                                   50807456528.26229
# 90                                                   4
# 91                            2022-09-15T02:26:00.000Z
# 92                                             0.99999
# ...
# 538                                          -13.71418
# 539                                           11.12776
# 540                                           28.17752
# 541                                  44531181437.15199
# 542                                            4.49140
# 543                                  55202599989.98000
# 544                           2022-09-15T02:26:00.000Z
# 545                         2022-09-15 02:28:08.062603
# 546                                               4687
# 547                                        Binance USD
# 548                                               BUSD
# 549                                        binance-usd
# 550                                               5086
# 551                           2019-09-20T00:00:00.000Z
# 552  [stablecoin, asset-backed-stablecoin, binance-...
# 553                                  20517253084.58926
# 554                                  20517253084.58926
# 555                                                  6
# 556                           2022-09-15T02:26:00.000Z
# 557                                            0.99914
# 558                                   9971169098.23416
# 559                                          -24.44170
# 560                                           -0.08409
# 561                                           -0.08645
# 562                                           -0.12018
# 563                                           -0.06862
# 564                                           -0.15318
# 565                                           -0.29739
# 566                                  20499546055.94763
# 567                                            2.07260
# 568                                  20499546055.95000
# 569                           2022-09-15T02:26:00.000Z
# 570                                         1839.00000
# 571                                                BNB
# 572                                                BNB
# 573                                                bnb
# 574                                           BUSD-BD1
# 575                         2022-09-15 02:28:08.062603
# 576                                                 52
# 577                                                XRP
# 578                                                XRP
# 579                                                xrp
# 580                                                814
# 581                           2013-08-04T00:00:00.000Z
# 582  [medium-of-exchange, enterprise-solutions, arr...
# 583                                 100000000000.00000
# 584                                  49826021773.00000
# 585                                  99989302361.00000
# 586                                                  7
# 587                           2022-09-15T02:26:00.000Z
# 588                                            0.33700
# 589                                   1207202475.12731
# 590                                          -16.55810
# 591                                           -0.87323
# 592                                            0.56496
# 593                                            1.49162
# 594                                           -9.44135
# 595                                           -3.79422
# 596                                            3.14098
# 597                                  16791329715.28789
# 598                                            1.69770
# 599                                  33699920478.87000
# 600                           2022-09-15T02:26:00.000Z
# 601                         2022-09-15 02:28:08.062603
# 602                                               2010
# 603                                            Cardano
# 604                                                ADA
# 605                                            cardano
# 606                                                569
# 607                           2017-10-01T00:00:00.000Z
# 608  [dpos, pos, platform, research, smart-contract...
# 609                                  45000000000.00000
# 610                                  34182044152.62900
# 611                                  34854947575.48000
# 612                                                  8
# 613                           2022-09-15T02:26:00.000Z
# 614                                            0.47319
# 615                                    732179300.43997
# 616                                          -26.89850
# 617                                           -0.80167
# 618                                            0.28683
# 619                                           -0.92560
# 620                                          -15.52760
# 621                                            4.59060
# 622                                           -3.35950
# 623                                  16174465973.04118
# 624                                            1.63450
# 625                                  21293371617.47000
# 626                           2022-09-15T02:26:00.000Z
# 627                         2022-09-15 02:28:08.062603
# 628                                               5426
# 629                                             Solana
# 630                                                SOL
# 631                                             solana
# 632                                                383
# 633                           2020-04-10T00:00:00.000Z
# 634  [pos, platform, solana-ecosystem, cms-holdings...
# 635                                    353848267.11550
# 636                                    511616946.14229
# 637                                                  9
# 638                           2022-09-15T02:26:00.000Z
# 639                                           33.51488
# 640                                    963134717.70034
# 641                                          -45.62860
# 642                                           -0.57820
# 643                                           -0.36760
# 644                                            3.11120
# 645                                          -23.26467
# 646                                          -15.13420
# 647                                            9.35802
# 648                                  11859180610.76805
# 649                                            1.19610
# 650                                  17146778242.81000
# 651                           2022-09-15T02:26:00.000Z
# 652                         2022-09-15 02:28:08.062603
# 653                                                 74
# 654                                           Dogecoin
# 655                                               DOGE
# 656                                           dogecoin
# 657                                                561
# 658                           2013-12-15T00:00:00.000Z
# 659  [mineable, pow, scrypt, medium-of-exchange, me...
# 660                                 132670764299.89409
# 661                                 132670764299.89409
# 662                                                 10
# 663                           2022-09-15T02:26:00.000Z
# 664                                            0.06035
# 665                                    359048609.66663
# 666                                          -21.94910
# 667                                           -0.97646
# 668                                           -0.00187
# 669                                           -1.00299
# 670                                          -23.57526
# 671                                           -5.70256
# 672                                            7.16875
# 673                                   8007009368.49166
# 674                                            0.80890
# 675                                   8007009368.49000
# 676                           2022-09-15T02:26:00.000Z
# 677                         2022-09-15 02:28:08.062603
# 678                                               6636
# 679                                           Polkadot
# 680                                                DOT
# 681                                       polkadot-new
# 682                                                410
# 683                           2020-08-19T00:00:00.000Z
# 684  [substrate, polkadot, binance-chain, polkadot-...
# 685                                   1132527619.33446
# 686                                   1232557368.87714
# 687                                                 11
# 688                                    904869778.00000
# 689                                   6365447627.83482
# 690                           2022-09-15T02:26:00.000Z
# 691                                            7.03466
# 692                                    321313192.91903
# 693                                          -32.78130
# 694                                           -0.88221
# 695                                           -2.04595
# 696                                           -2.40243
# 697                                          -20.13428
# 698                                           -1.07761
# 699                                           -3.28148
# 700                                   7966942231.05101
# 701                                            0.80510
# 702                                   8670617110.49000
# 703                           2022-09-15T02:26:00.000Z
# 704                         2022-09-15 02:28:08.062603
# 705                                               3890
# 706                                            Polygon
# 707                                              MATIC
# 708                                            polygon
# 709                                                484
# 710                           2019-04-28T00:00:00.000Z
# 711  [platform, enterprise-solutions, scaling, stat...
# 712                                  10000000000.00000
# 713                                   8734317475.28493
# 714                                  10000000000.00000
# 715                                                 12
# 716                           2022-09-15T02:26:00.000Z
# 717                                            0.84798
# 718                                    405637500.02957
# 719                                          -42.90480
# 720                                           -0.50219
# 721                                           -1.80370
# 722                                            0.57742
# 723                                          -11.47706
# 724                                           17.08748
# 725                                          116.70833
# 726                                   7406553454.09451
# 727                                            0.74700
# 728                                   8479830822.56000
# 729                           2022-09-15T02:26:00.000Z
# 730                         2022-09-15 02:28:08.062603
# 731                                               4943
# 732                                                Dai
# 733                                                DAI
# 734                               multi-collateral-dai
# 735                                               1336
# 736                           2019-11-22T00:00:00.000Z
# 737  [defi, stablecoin, asset-backed-stablecoin, et...
# 738                                   6839924162.06719
# 739                                   6839924162.06719
# 740                                                 13
# 741                           2022-09-15T02:26:00.000Z
# 742                                            0.99905
# 743                                    697775705.01893
# 744                                          -18.53650
# 745                                           -0.02721
# 746                                           -0.11066
# 747                                           -0.10025
# 748                                           -0.03827
# 749                                           -0.02871
# 750                                           -0.14976
# 751                                   6833452966.48641
# 752                                            0.69030
# 753                                   6833452966.49000
# 754                           2022-09-15T02:26:00.000Z
# 755                                         1027.00000
# 756                                           Ethereum
# 757                                                ETH
# 758                                           ethereum
# 759         0x6b175474e89094c44da98b954eedeac495271d0f
# 760                         2022-09-15 02:28:08.062603
# 761                                               5994
# 762                                          Shiba Inu
# 763                                               SHIB
# 764                                          shiba-inu
# 765                                                413
# 766                           2020-08-01T00:00:00.000Z
# 767      [memes, ethereum-ecosystem, doggone-doggerel]
# 768                              549063278876301.93750
# 769                              589735030408322.75000
# 770                                                 14
# 771                           2022-09-15T02:26:00.000Z
# 772                                            0.00001
# 773                                    311367632.30440
# 774                                          -31.94350
# 775                                           -0.53287
# 776                                           -1.88842
# 777                                           -1.64927
# 778                                          -22.74841
# 779                                           10.30389
# 780                                           47.27949
# 781                                   6620943027.27813
# 782                                            0.66910
# 783                                   7111388045.32000
# 784                           2022-09-15T02:26:00.000Z
# 785                                         1027.00000
# 786                                           Ethereum
# 787                                                ETH
# 788                                           ethereum
# 789         0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 790                         2022-09-15 02:28:08.062603
# 791                                               1958
# 792                                               TRON
# 793                                                TRX
# 794                                               tron
# 795                                                684
# 796                           2017-09-13T00:00:00.000Z
# 797                  [media, payments, tron-ecosystem]
# 798                                  92366671484.34125
# 799                                  92366665415.80617
# 800                                                 15
# 801                                  71659659264.00000
# 802                                   4373125246.45869
# 803                           2022-09-15T02:26:00.000Z
# 804                                            0.06103
# 805                                    349859652.37644
# 806                                          -13.99280
# 807                                           -0.43845
# 808                                           -0.29978
# 809                                            0.50735
# 810                                          -11.43989
# 811                                          -11.03340
# 812                                           -1.48665
# 813                                   5636797985.75951
# 814                                            0.56850
# 815                                   5636797615.42000
# 816                           2022-09-15T02:26:00.000Z
# 817                         2022-09-15 02:28:08.062603

# %%
df5 = df4.rename(columns={'level_1': 'percent_change'})
df5
# Out:
#      level_0                      percent_change  \
# 0          0                                  id
# 1          0                                name
# 2          0                              symbol
# 3          0                                slug
# 4          0                    num_market_pairs
# 5          0                          date_added
# 6          0                                tags
# 7          0                          max_supply
# 8          0                  circulating_supply
# 9          0                        total_supply
# 10         0                            cmc_rank
# 11         0                        last_updated
# 12         0                     quote.USD.price
# 13         0                quote.USD.volume_24h
# 14         0         quote.USD.volume_change_24h
# 15         0         quote.USD.percent_change_1h
# 16         0        quote.USD.percent_change_24h
# 17         0         quote.USD.percent_change_7d
# 18         0        quote.USD.percent_change_30d
# 19         0        quote.USD.percent_change_60d
# 20         0        quote.USD.percent_change_90d
# 21         0                quote.USD.market_cap
# 22         0      quote.USD.market_cap_dominance
# 23         0  quote.USD.fully_diluted_market_cap
# 24         0              quote.USD.last_updated
# 25         0                           timestamp
# 26         1                                  id
# 27         1                                name
# 28         1                              symbol
# 29         1                                slug
# 30         1                    num_market_pairs
# 31         1                          date_added
# 32         1                                tags
# 33         1                  circulating_supply
# 34         1                        total_supply
# 35         1                            cmc_rank
# 36         1                        last_updated
# 37         1                     quote.USD.price
# 38         1                quote.USD.volume_24h
# 39         1         quote.USD.volume_change_24h
# 40         1         quote.USD.percent_change_1h
# 41         1        quote.USD.percent_change_24h
# 42         1         quote.USD.percent_change_7d
# 43         1        quote.USD.percent_change_30d
# 44         1        quote.USD.percent_change_60d
# 45         1        quote.USD.percent_change_90d
# 46         1                quote.USD.market_cap
# 47         1      quote.USD.market_cap_dominance
# 48         1  quote.USD.fully_diluted_market_cap
# 49         1              quote.USD.last_updated
# 50         1                           timestamp
# 51         2                                  id
# 52         2                                name
# 53         2                              symbol
# 54         2                                slug
# 55         2                    num_market_pairs
# 56         2                          date_added
# 57         2                                tags
# 58         2                  circulating_supply
# 59         2                        total_supply
# 60         2                            cmc_rank
# 61         2                        last_updated
# 62         2                     quote.USD.price
# 63         2                quote.USD.volume_24h
# 64         2         quote.USD.volume_change_24h
# 65         2         quote.USD.percent_change_1h
# 66         2        quote.USD.percent_change_24h
# 67         2         quote.USD.percent_change_7d
# 68         2        quote.USD.percent_change_30d
# 69         2        quote.USD.percent_change_60d
# 70         2        quote.USD.percent_change_90d
# 71         2                quote.USD.market_cap
# 72         2      quote.USD.market_cap_dominance
# 73         2  quote.USD.fully_diluted_market_cap
# 74         2              quote.USD.last_updated
# 75         2                         platform.id
# 76         2                       platform.name
# 77         2                     platform.symbol
# 78         2                       platform.slug
# 79         2              platform.token_address
# 80         2                           timestamp
# 81         3                                  id
# 82         3                                name
# 83         3                              symbol
# 84         3                                slug
# 85         3                    num_market_pairs
# 86         3                          date_added
# 87         3                                tags
# 88         3                  circulating_supply
# 89         3                        total_supply
# 90         3                            cmc_rank
# 91         3                        last_updated
# 92         3                     quote.USD.price
# 93         3                quote.USD.volume_24h
# 94         3         quote.USD.volume_change_24h
# 95         3         quote.USD.percent_change_1h
# 96         3        quote.USD.percent_change_24h
# 97         3         quote.USD.percent_change_7d
# 98         3        quote.USD.percent_change_30d
# 99         3        quote.USD.percent_change_60d
# 100        3        quote.USD.percent_change_90d
# 101        3                quote.USD.market_cap
# 102        3      quote.USD.market_cap_dominance
# 103        3  quote.USD.fully_diluted_market_cap
# 104        3              quote.USD.last_updated
# 105        3                         platform.id
# 106        3                       platform.name
# 107        3                     platform.symbol
# 108        3                       platform.slug
# 109        3              platform.token_address
# 110        3                           timestamp
# 111        4                                  id
# 112        4                                name
# 113        4                              symbol
# 114        4                                slug
# 115        4                    num_market_pairs
# 116        4                          date_added
# 117        4                                tags
# 118        4                          max_supply
# 119        4                  circulating_supply
# 120        4                        total_supply
# 121        4                            cmc_rank
# 122        4                        last_updated
# 123        4                     quote.USD.price
# 124        4                quote.USD.volume_24h
# 125        4         quote.USD.volume_change_24h
# 126        4         quote.USD.percent_change_1h
# 127        4        quote.USD.percent_change_24h
# 128        4         quote.USD.percent_change_7d
# 129        4        quote.USD.percent_change_30d
# 130        4        quote.USD.percent_change_60d
# 131        4        quote.USD.percent_change_90d
# 132        4                quote.USD.market_cap
# 133        4      quote.USD.market_cap_dominance
# 134        4  quote.USD.fully_diluted_market_cap
# 135        4              quote.USD.last_updated
# 136        4                           timestamp
# 137        5                                  id
# 138        5                                name
# 139        5                              symbol
# 140        5                                slug
# 141        5                    num_market_pairs
# 142        5                          date_added
# 143        5                                tags
# 144        5                  circulating_supply
# 145        5                        total_supply
# 146        5                            cmc_rank
# 147        5                        last_updated
# 148        5                     quote.USD.price
# 149        5                quote.USD.volume_24h
# 150        5         quote.USD.volume_change_24h
# 151        5         quote.USD.percent_change_1h
# 152        5        quote.USD.percent_change_24h
# 153        5         quote.USD.percent_change_7d
# 154        5        quote.USD.percent_change_30d
# 155        5        quote.USD.percent_change_60d
# 156        5        quote.USD.percent_change_90d
# 157        5                quote.USD.market_cap
# 158        5      quote.USD.market_cap_dominance
# 159        5  quote.USD.fully_diluted_market_cap
# 160        5              quote.USD.last_updated
# 161        5                         platform.id
# 162        5                       platform.name
# 163        5                     platform.symbol
# 164        5                       platform.slug
# 165        5              platform.token_address
# 166        5                           timestamp
# 167        6                                  id
# 168        6                                name
# 169        6                              symbol
# 170        6                                slug
# 171        6                    num_market_pairs
# 172        6                          date_added
# 173        6                                tags
# 174        6                          max_supply
# 175        6                  circulating_supply
# 176        6                        total_supply
# 177        6                            cmc_rank
# 178        6                        last_updated
# 179        6                     quote.USD.price
# 180        6                quote.USD.volume_24h
# 181        6         quote.USD.volume_change_24h
# 182        6         quote.USD.percent_change_1h
# 183        6        quote.USD.percent_change_24h
# 184        6         quote.USD.percent_change_7d
# 185        6        quote.USD.percent_change_30d
# 186        6        quote.USD.percent_change_60d
# 187        6        quote.USD.percent_change_90d
# 188        6                quote.USD.market_cap
# 189        6      quote.USD.market_cap_dominance
# 190        6  quote.USD.fully_diluted_market_cap
# 191        6              quote.USD.last_updated
# 192        6                           timestamp
# 193        7                                  id
# 194        7                                name
# 195        7                              symbol
# 196        7                                slug
# 197        7                    num_market_pairs
# 198        7                          date_added
# 199        7                                tags
# 200        7                          max_supply
# 201        7                  circulating_supply
# 202        7                        total_supply
# 203        7                            cmc_rank
# 204        7                        last_updated
# 205        7                     quote.USD.price
# 206        7                quote.USD.volume_24h
# 207        7         quote.USD.volume_change_24h
# 208        7         quote.USD.percent_change_1h
# 209        7        quote.USD.percent_change_24h
# 210        7         quote.USD.percent_change_7d
# 211        7        quote.USD.percent_change_30d
# 212        7        quote.USD.percent_change_60d
# 213        7        quote.USD.percent_change_90d
# 214        7                quote.USD.market_cap
# 215        7      quote.USD.market_cap_dominance
# 216        7  quote.USD.fully_diluted_market_cap
# 217        7              quote.USD.last_updated
# 218        7                           timestamp
# 219        8                                  id
# 220        8                                name
# 221        8                              symbol
# 222        8                                slug
# 223        8                    num_market_pairs
# 224        8                          date_added
# 225        8                                tags
# 226        8                  circulating_supply
# 227        8                        total_supply
# 228        8                            cmc_rank
# 229        8                        last_updated
# 230        8                     quote.USD.price
# 231        8                quote.USD.volume_24h
# 232        8         quote.USD.volume_change_24h
# 233        8         quote.USD.percent_change_1h
# 234        8        quote.USD.percent_change_24h
# 235        8         quote.USD.percent_change_7d
# 236        8        quote.USD.percent_change_30d
# 237        8        quote.USD.percent_change_60d
# 238        8        quote.USD.percent_change_90d
# 239        8                quote.USD.market_cap
# 240        8      quote.USD.market_cap_dominance
# 241        8  quote.USD.fully_diluted_market_cap
# 242        8              quote.USD.last_updated
# 243        8                           timestamp
# 244        9                                  id
# 245        9                                name
# 246        9                              symbol
# 247        9                                slug
# 248        9                    num_market_pairs
# 249        9                          date_added
# 250        9                                tags
# 251        9                  circulating_supply
# 252        9                        total_supply
# 253        9                            cmc_rank
# 254        9                        last_updated
# 255        9                     quote.USD.price
# 256        9                quote.USD.volume_24h
# 257        9         quote.USD.volume_change_24h
# 258        9         quote.USD.percent_change_1h
# 259        9        quote.USD.percent_change_24h
# 260        9         quote.USD.percent_change_7d
# 261        9        quote.USD.percent_change_30d
# 262        9        quote.USD.percent_change_60d
# 263        9        quote.USD.percent_change_90d
# 264        9                quote.USD.market_cap
# 265        9      quote.USD.market_cap_dominance
# 266        9  quote.USD.fully_diluted_market_cap
# 267        9              quote.USD.last_updated
# 268        9                           timestamp
# 269       10                                  id
# 270       10                                name
# 271       10                              symbol
# 272       10                                slug
# 273       10                    num_market_pairs
# 274       10                          date_added
# 275       10                                tags
# 276       10                  circulating_supply
# 277       10                        total_supply
# 278       10                            cmc_rank
# 279       10    self_reported_circulating_supply
# 280       10            self_reported_market_cap
# 281       10                        last_updated
# 282       10                     quote.USD.price
# 283       10                quote.USD.volume_24h
# 284       10         quote.USD.volume_change_24h
# 285       10         quote.USD.percent_change_1h
# 286       10        quote.USD.percent_change_24h
# 287       10         quote.USD.percent_change_7d
# 288       10        quote.USD.percent_change_30d
# 289       10        quote.USD.percent_change_60d
# 290       10        quote.USD.percent_change_90d
# 291       10                quote.USD.market_cap
# 292       10      quote.USD.market_cap_dominance
# 293       10  quote.USD.fully_diluted_market_cap
# 294       10              quote.USD.last_updated
# 295       10                           timestamp
# 296       11                                  id
# 297       11                                name
# 298       11                              symbol
# 299       11                                slug
# 300       11                    num_market_pairs
# 301       11                          date_added
# 302       11                                tags
# 303       11                          max_supply
# 304       11                  circulating_supply
# 305       11                        total_supply
# 306       11                            cmc_rank
# 307       11                        last_updated
# 308       11                     quote.USD.price
# 309       11                quote.USD.volume_24h
# 310       11         quote.USD.volume_change_24h
# 311       11         quote.USD.percent_change_1h
# 312       11        quote.USD.percent_change_24h
# 313       11         quote.USD.percent_change_7d
# 314       11        quote.USD.percent_change_30d
# 315       11        quote.USD.percent_change_60d
# 316       11        quote.USD.percent_change_90d
# 317       11                quote.USD.market_cap
# 318       11      quote.USD.market_cap_dominance
# 319       11  quote.USD.fully_diluted_market_cap
# 320       11              quote.USD.last_updated
# 321       11                           timestamp
# 322       12                                  id
# 323       12                                name
# 324       12                              symbol
# 325       12                                slug
# 326       12                    num_market_pairs
# 327       12                          date_added
# 328       12                                tags
# 329       12                  circulating_supply
# 330       12                        total_supply
# 331       12                            cmc_rank
# 332       12                        last_updated
# 333       12                     quote.USD.price
# 334       12                quote.USD.volume_24h
# 335       12         quote.USD.volume_change_24h
# 336       12         quote.USD.percent_change_1h
# 337       12        quote.USD.percent_change_24h
# 338       12         quote.USD.percent_change_7d
# 339       12        quote.USD.percent_change_30d
# 340       12        quote.USD.percent_change_60d
# 341       12        quote.USD.percent_change_90d
# 342       12                quote.USD.market_cap
# 343       12      quote.USD.market_cap_dominance
# 344       12  quote.USD.fully_diluted_market_cap
# 345       12              quote.USD.last_updated
# 346       12                         platform.id
# 347       12                       platform.name
# 348       12                     platform.symbol
# 349       12                       platform.slug
# 350       12              platform.token_address
# 351       12                           timestamp
# 352       13                                  id
# 353       13                                name
# 354       13                              symbol
# 355       13                                slug
# 356       13                    num_market_pairs
# 357       13                          date_added
# 358       13                                tags
# 359       13                  circulating_supply
# 360       13                        total_supply
# 361       13                            cmc_rank
# 362       13                        last_updated
# 363       13                     quote.USD.price
# 364       13                quote.USD.volume_24h
# 365       13         quote.USD.volume_change_24h
# 366       13         quote.USD.percent_change_1h
# 367       13        quote.USD.percent_change_24h
# 368       13         quote.USD.percent_change_7d
# 369       13        quote.USD.percent_change_30d
# 370       13        quote.USD.percent_change_60d
# 371       13        quote.USD.percent_change_90d
# 372       13                quote.USD.market_cap
# 373       13      quote.USD.market_cap_dominance
# 374       13  quote.USD.fully_diluted_market_cap
# 375       13              quote.USD.last_updated
# 376       13                         platform.id
# 377       13                       platform.name
# 378       13                     platform.symbol
# 379       13                       platform.slug
# 380       13              platform.token_address
# 381       13                           timestamp
# 382       14                                  id
# 383       14                                name
# 384       14                              symbol
# 385       14                                slug
# 386       14                    num_market_pairs
# 387       14                          date_added
# 388       14                                tags
# 389       14                  circulating_supply
# 390       14                        total_supply
# 391       14                            cmc_rank
# 392       14    self_reported_circulating_supply
# 393       14            self_reported_market_cap
# 394       14                        last_updated
# 395       14                     quote.USD.price
# 396       14                quote.USD.volume_24h
# 397       14         quote.USD.volume_change_24h
# 398       14         quote.USD.percent_change_1h
# 399       14        quote.USD.percent_change_24h
# 400       14         quote.USD.percent_change_7d
# 401       14        quote.USD.percent_change_30d
# 402       14        quote.USD.percent_change_60d
# 403       14        quote.USD.percent_change_90d
# 404       14                quote.USD.market_cap
# 405       14      quote.USD.market_cap_dominance
# 406       14  quote.USD.fully_diluted_market_cap
# 407       14              quote.USD.last_updated
# 408       14                           timestamp
# 409        0                                  id
# 410        0                                name
# 411        0                              symbol
# 412        0                                slug
# 413        0                    num_market_pairs
# 414        0                          date_added
# 415        0                                tags
# 416        0                          max_supply
# 417        0                  circulating_supply
# 418        0                        total_supply
# 419        0                            cmc_rank
# 420        0                        last_updated
# 421        0                     quote.USD.price
# 422        0                quote.USD.volume_24h
# 423        0         quote.USD.volume_change_24h
# 424        0         quote.USD.percent_change_1h
# 425        0        quote.USD.percent_change_24h
# 426        0         quote.USD.percent_change_7d
# 427        0        quote.USD.percent_change_30d
# 428        0        quote.USD.percent_change_60d
# 429        0        quote.USD.percent_change_90d
# 430        0                quote.USD.market_cap
# 431        0      quote.USD.market_cap_dominance
# 432        0  quote.USD.fully_diluted_market_cap
# 433        0              quote.USD.last_updated
# 434        0                           timestamp
# 435        1                                  id
# 436        1                                name
# 437        1                              symbol
# 438        1                                slug
# 439        1                    num_market_pairs
# 440        1                          date_added
# 441        1                                tags
# 442        1                  circulating_supply
# 443        1                        total_supply
# 444        1                            cmc_rank
# 445        1                        last_updated
# 446        1                     quote.USD.price
# 447        1                quote.USD.volume_24h
# 448        1         quote.USD.volume_change_24h
# 449        1         quote.USD.percent_change_1h
# 450        1        quote.USD.percent_change_24h
# 451        1         quote.USD.percent_change_7d
# 452        1        quote.USD.percent_change_30d
# 453        1        quote.USD.percent_change_60d
# 454        1        quote.USD.percent_change_90d
# 455        1                quote.USD.market_cap
# 456        1      quote.USD.market_cap_dominance
# 457        1  quote.USD.fully_diluted_market_cap
# 458        1              quote.USD.last_updated
# 459        1                           timestamp
# 460        2                                  id
# 461        2                                name
# 462        2                              symbol
# 463        2                                slug
# 464        2                    num_market_pairs
# 465        2                          date_added
# 466        2                                tags
# 467        2                  circulating_supply
# 468        2                        total_supply
# 469        2                            cmc_rank
# 470        2                        last_updated
# 471        2                     quote.USD.price
# 472        2                quote.USD.volume_24h
# 473        2         quote.USD.volume_change_24h
# 474        2         quote.USD.percent_change_1h
# 475        2        quote.USD.percent_change_24h
# 476        2         quote.USD.percent_change_7d
# 477        2        quote.USD.percent_change_30d
# 478        2        quote.USD.percent_change_60d
# 479        2        quote.USD.percent_change_90d
# 480        2                quote.USD.market_cap
# 481        2      quote.USD.market_cap_dominance
# 482        2  quote.USD.fully_diluted_market_cap
# 483        2              quote.USD.last_updated
# 484        2                         platform.id
# 485        2                       platform.name
# 486        2                     platform.symbol
# 487        2                       platform.slug
# 488        2              platform.token_address
# 489        2                           timestamp
# 490        3                                  id
# 491        3                                name
# 492        3                              symbol
# 493        3                                slug
# 494        3                    num_market_pairs
# 495        3                          date_added
# 496        3                                tags
# 497        3                  circulating_supply
# 498        3                        total_supply
# 499        3                            cmc_rank
# 500        3                        last_updated
# 501        3                     quote.USD.price
# 502        3                quote.USD.volume_24h
# 503        3         quote.USD.volume_change_24h
# 504        3         quote.USD.percent_change_1h
# 505        3        quote.USD.percent_change_24h
# 506        3         quote.USD.percent_change_7d
# 507        3        quote.USD.percent_change_30d
# 508        3        quote.USD.percent_change_60d
# 509        3        quote.USD.percent_change_90d
# 510        3                quote.USD.market_cap
# 511        3      quote.USD.market_cap_dominance
# 512        3  quote.USD.fully_diluted_market_cap
# 513        3              quote.USD.last_updated
# 514        3                         platform.id
# 515        3                       platform.name
# 516        3                     platform.symbol
# 517        3                       platform.slug
# 518        3              platform.token_address
# 519        3                           timestamp
# 520        4                                  id
# 521        4                                name
# 522        4                              symbol
# 523        4                                slug
# 524        4                    num_market_pairs
# 525        4                          date_added
# 526        4                                tags
# 527        4                          max_supply
# 528        4                  circulating_supply
# 529        4                        total_supply
# 530        4                            cmc_rank
# 531        4                        last_updated
# 532        4                     quote.USD.price
# 533        4                quote.USD.volume_24h
# 534        4         quote.USD.volume_change_24h
# 535        4         quote.USD.percent_change_1h
# 536        4        quote.USD.percent_change_24h
# 537        4         quote.USD.percent_change_7d
# 538        4        quote.USD.percent_change_30d
# 539        4        quote.USD.percent_change_60d
# 540        4        quote.USD.percent_change_90d
# 541        4                quote.USD.market_cap
# 542        4      quote.USD.market_cap_dominance
# 543        4  quote.USD.fully_diluted_market_cap
# 544        4              quote.USD.last_updated
# 545        4                           timestamp
# 546        5                                  id
# 547        5                                name
# 548        5                              symbol
# 549        5                                slug
# 550        5                    num_market_pairs
# 551        5                          date_added
# 552        5                                tags
# 553        5                  circulating_supply
# 554        5                        total_supply
# 555        5                            cmc_rank
# 556        5                        last_updated
# 557        5                     quote.USD.price
# 558        5                quote.USD.volume_24h
# 559        5         quote.USD.volume_change_24h
# 560        5         quote.USD.percent_change_1h
# 561        5        quote.USD.percent_change_24h
# 562        5         quote.USD.percent_change_7d
# 563        5        quote.USD.percent_change_30d
# 564        5        quote.USD.percent_change_60d
# 565        5        quote.USD.percent_change_90d
# 566        5                quote.USD.market_cap
# 567        5      quote.USD.market_cap_dominance
# 568        5  quote.USD.fully_diluted_market_cap
# 569        5              quote.USD.last_updated
# 570        5                         platform.id
# 571        5                       platform.name
# 572        5                     platform.symbol
# 573        5                       platform.slug
# 574        5              platform.token_address
# 575        5                           timestamp
# 576        6                                  id
# 577        6                                name
# 578        6                              symbol
# 579        6                                slug
# 580        6                    num_market_pairs
# 581        6                          date_added
# 582        6                                tags
# 583        6                          max_supply
# 584        6                  circulating_supply
# 585        6                        total_supply
# 586        6                            cmc_rank
# 587        6                        last_updated
# 588        6                     quote.USD.price
# 589        6                quote.USD.volume_24h
# 590        6         quote.USD.volume_change_24h
# 591        6         quote.USD.percent_change_1h
# 592        6        quote.USD.percent_change_24h
# 593        6         quote.USD.percent_change_7d
# 594        6        quote.USD.percent_change_30d
# 595        6        quote.USD.percent_change_60d
# 596        6        quote.USD.percent_change_90d
# 597        6                quote.USD.market_cap
# 598        6      quote.USD.market_cap_dominance
# 599        6  quote.USD.fully_diluted_market_cap
# 600        6              quote.USD.last_updated
# 601        6                           timestamp
# 602        7                                  id
# 603        7                                name
# 604        7                              symbol
# 605        7                                slug
# 606        7                    num_market_pairs
# 607        7                          date_added
# 608        7                                tags
# 609        7                          max_supply
# 610        7                  circulating_supply
# 611        7                        total_supply
# 612        7                            cmc_rank
# 613        7                        last_updated
# 614        7                     quote.USD.price
# 615        7                quote.USD.volume_24h
# 616        7         quote.USD.volume_change_24h
# 617        7         quote.USD.percent_change_1h
# 618        7        quote.USD.percent_change_24h
# 619        7         quote.USD.percent_change_7d
# 620        7        quote.USD.percent_change_30d
# 621        7        quote.USD.percent_change_60d
# 622        7        quote.USD.percent_change_90d
# 623        7                quote.USD.market_cap
# 624        7      quote.USD.market_cap_dominance
# 625        7  quote.USD.fully_diluted_market_cap
# 626        7              quote.USD.last_updated
# 627        7                           timestamp
# 628        8                                  id
# 629        8                                name
# 630        8                              symbol
# 631        8                                slug
# 632        8                    num_market_pairs
# 633        8                          date_added
# 634        8                                tags
# 635        8                  circulating_supply
# 636        8                        total_supply
# 637        8                            cmc_rank
# 638        8                        last_updated
# 639        8                     quote.USD.price
# 640        8                quote.USD.volume_24h
# 641        8         quote.USD.volume_change_24h
# 642        8         quote.USD.percent_change_1h
# 643        8        quote.USD.percent_change_24h
# 644        8         quote.USD.percent_change_7d
# 645        8        quote.USD.percent_change_30d
# 646        8        quote.USD.percent_change_60d
# 647        8        quote.USD.percent_change_90d
# 648        8                quote.USD.market_cap
# 649        8      quote.USD.market_cap_dominance
# 650        8  quote.USD.fully_diluted_market_cap
# 651        8              quote.USD.last_updated
# 652        8                           timestamp
# 653        9                                  id
# 654        9                                name
# 655        9                              symbol
# 656        9                                slug
# 657        9                    num_market_pairs
# 658        9                          date_added
# 659        9                                tags
# 660        9                  circulating_supply
# 661        9                        total_supply
# 662        9                            cmc_rank
# 663        9                        last_updated
# 664        9                     quote.USD.price
# 665        9                quote.USD.volume_24h
# 666        9         quote.USD.volume_change_24h
# 667        9         quote.USD.percent_change_1h
# 668        9        quote.USD.percent_change_24h
# 669        9         quote.USD.percent_change_7d
# 670        9        quote.USD.percent_change_30d
# 671        9        quote.USD.percent_change_60d
# 672        9        quote.USD.percent_change_90d
# 673        9                quote.USD.market_cap
# 674        9      quote.USD.market_cap_dominance
# 675        9  quote.USD.fully_diluted_market_cap
# 676        9              quote.USD.last_updated
# 677        9                           timestamp
# 678       10                                  id
# 679       10                                name
# 680       10                              symbol
# 681       10                                slug
# 682       10                    num_market_pairs
# 683       10                          date_added
# 684       10                                tags
# 685       10                  circulating_supply
# 686       10                        total_supply
# 687       10                            cmc_rank
# 688       10    self_reported_circulating_supply
# 689       10            self_reported_market_cap
# 690       10                        last_updated
# 691       10                     quote.USD.price
# 692       10                quote.USD.volume_24h
# 693       10         quote.USD.volume_change_24h
# 694       10         quote.USD.percent_change_1h
# 695       10        quote.USD.percent_change_24h
# 696       10         quote.USD.percent_change_7d
# 697       10        quote.USD.percent_change_30d
# 698       10        quote.USD.percent_change_60d
# 699       10        quote.USD.percent_change_90d
# 700       10                quote.USD.market_cap
# 701       10      quote.USD.market_cap_dominance
# 702       10  quote.USD.fully_diluted_market_cap
# 703       10              quote.USD.last_updated
# 704       10                           timestamp
# 705       11                                  id
# 706       11                                name
# 707       11                              symbol
# 708       11                                slug
# 709       11                    num_market_pairs
# 710       11                          date_added
# 711       11                                tags
# 712       11                          max_supply
# 713       11                  circulating_supply
# 714       11                        total_supply
# 715       11                            cmc_rank
# 716       11                        last_updated
# 717       11                     quote.USD.price
# 718       11                quote.USD.volume_24h
# 719       11         quote.USD.volume_change_24h
# 720       11         quote.USD.percent_change_1h
# 721       11        quote.USD.percent_change_24h
# 722       11         quote.USD.percent_change_7d
# 723       11        quote.USD.percent_change_30d
# 724       11        quote.USD.percent_change_60d
# 725       11        quote.USD.percent_change_90d
# 726       11                quote.USD.market_cap
# 727       11      quote.USD.market_cap_dominance
# 728       11  quote.USD.fully_diluted_market_cap
# 729       11              quote.USD.last_updated
# 730       11                           timestamp
# 731       12                                  id
# 732       12                                name
# 733       12                              symbol
# 734       12                                slug
# 735       12                    num_market_pairs
# 736       12                          date_added
# 737       12                                tags
# 738       12                  circulating_supply
# 739       12                        total_supply
# 740       12                            cmc_rank
# 741       12                        last_updated
# 742       12                     quote.USD.price
# 743       12                quote.USD.volume_24h
# 744       12         quote.USD.volume_change_24h
# 745       12         quote.USD.percent_change_1h
# 746       12        quote.USD.percent_change_24h
# 747       12         quote.USD.percent_change_7d
# 748       12        quote.USD.percent_change_30d
# 749       12        quote.USD.percent_change_60d
# 750       12        quote.USD.percent_change_90d
# 751       12                quote.USD.market_cap
# 752       12      quote.USD.market_cap_dominance
# 753       12  quote.USD.fully_diluted_market_cap
# 754       12              quote.USD.last_updated
# 755       12                         platform.id
# 756       12                       platform.name
# 757       12                     platform.symbol
# 758       12                       platform.slug
# 759       12              platform.token_address
# 760       12                           timestamp
# 761       13                                  id
# 762       13                                name
# 763       13                              symbol
# 764       13                                slug
# 765       13                    num_market_pairs
# 766       13                          date_added
# 767       13                                tags
# 768       13                  circulating_supply
# 769       13                        total_supply
# 770       13                            cmc_rank
# 771       13                        last_updated
# 772       13                     quote.USD.price
# 773       13                quote.USD.volume_24h
# 774       13         quote.USD.volume_change_24h
# 775       13         quote.USD.percent_change_1h
# 776       13        quote.USD.percent_change_24h
# 777       13         quote.USD.percent_change_7d
# 778       13        quote.USD.percent_change_30d
# 779       13        quote.USD.percent_change_60d
# 780       13        quote.USD.percent_change_90d
# 781       13                quote.USD.market_cap
# 782       13      quote.USD.market_cap_dominance
# 783       13  quote.USD.fully_diluted_market_cap
# 784       13              quote.USD.last_updated
# 785       13                         platform.id
# 786       13                       platform.name
# 787       13                     platform.symbol
# 788       13                       platform.slug
# 789       13              platform.token_address
# 790       13                           timestamp
# 791       14                                  id
# 792       14                                name
# 793       14                              symbol
# 794       14                                slug
# 795       14                    num_market_pairs
# 796       14                          date_added
# 797       14                                tags
# 798       14                  circulating_supply
# 799       14                        total_supply
# 800       14                            cmc_rank
# 801       14    self_reported_circulating_supply
# 802       14            self_reported_market_cap
# 803       14                        last_updated
# 804       14                     quote.USD.price
# 805       14                quote.USD.volume_24h
# 806       14         quote.USD.volume_change_24h
# 807       14         quote.USD.percent_change_1h
# 808       14        quote.USD.percent_change_24h
# 809       14         quote.USD.percent_change_7d
# 810       14        quote.USD.percent_change_30d
# 811       14        quote.USD.percent_change_60d
# 812       14        quote.USD.percent_change_90d
# 813       14                quote.USD.market_cap
# 814       14      quote.USD.market_cap_dominance
# 815       14  quote.USD.fully_diluted_market_cap
# 816       14              quote.USD.last_updated
# 817       14                           timestamp
#
#                                                   name
# 0                                                    1
# 1                                              Bitcoin
# 2                                                  BTC
# 3                                              bitcoin
# 4                                                 9740
# 5                             2013-04-28T00:00:00.000Z
# 6    [mineable, pow, sha-256, store-of-value, state...
# 7                                       21000000.00000
# 8                                       19150881.00000
# 9                                       19150881.00000
# 10                                                   1
# 11                            2022-09-15T02:26:00.000Z
# 12                                         20086.21755
# 13                                   37719571572.83210
# 14                                           -26.45510
# 15                                             0.03897
# 16                                            -1.85478
# 17                                             4.35521
# 18                                           -16.81022
# 19                                            -5.14920
# 20                                            -3.26165
# 21                                  384668762102.85425
# 22                                            38.89130
# 23                                  421810568618.75000
# 24                            2022-09-15T02:26:00.000Z
# 25                          2022-09-15 02:28:08.062603
# 26                                                1027
# 27                                            Ethereum
# 28                                                 ETH
# 29                                            ethereum
# 30                                                6089
# 31                            2015-08-07T00:00:00.000Z
# 32   [mineable, pow, smart-contracts, ethereum-ecos...
# 33                                     122371557.43650
# 34                                     122371557.43650
# 35                                                   2
# 36                            2022-09-15T02:26:00.000Z
# 37                                          1611.22227
# 38                                   18789703865.52800
# 39                                           -18.83000
# 40                                            -0.09766
# 41                                             1.02032
# 42                                            -0.84751
# 43                                           -15.29056
# 44                                            20.22622
# 45                                            46.92122
# 46                                  197167778257.05331
# 47                                            19.92480
# 48                                  197167778257.04999
# 49                            2022-09-15T02:26:00.000Z
# 50                          2022-09-15 02:28:08.062603
# 51                                                 825
# 52                                              Tether
# 53                                                USDT
# 54                                              tether
# 55                                               39680
# 56                            2015-02-25T00:00:00.000Z
# 57   [payments, stablecoin, asset-backed-stablecoin...
# 58                                   67883438459.35066
# 59                                   69156782826.32211
# 60                                                   3
# 61                            2022-09-15T02:26:00.000Z
# 62                                             1.00014
# 63                                   55809535836.12127
# 64                                           -22.10730
# 65                                            -0.00447
# 66                                             0.01103
# 67                                             0.00254
# 68                                            -0.00488
# 69                                             0.03523
# 70                                             0.12741
# 71                                   67892702396.38782
# 72                                             6.84760
# 73                                   69166220534.49001
# 74                            2022-09-15T02:26:00.000Z
# 75                                          1027.00000
# 76                                            Ethereum
# 77                                                 ETH
# 78                                            ethereum
# 79          0xdac17f958d2ee523a2206206994597c13d831ec7
# 80                          2022-09-15 02:28:08.062603
# 81                                                3408
# 82                                            USD Coin
# 83                                                USDC
# 84                                            usd-coin
# 85                                                6195
# 86                            2018-10-08T00:00:00.000Z
# 87   [medium-of-exchange, stablecoin, asset-backed-...
# 88                                   50807456528.26229
# 89                                   50807456528.26229
# 90                                                   4
# 91                            2022-09-15T02:26:00.000Z
# 92                                             0.99999
# ...
# 538                                          -13.71418
# 539                                           11.12776
# 540                                           28.17752
# 541                                  44531181437.15199
# 542                                            4.49140
# 543                                  55202599989.98000
# 544                           2022-09-15T02:26:00.000Z
# 545                         2022-09-15 02:28:08.062603
# 546                                               4687
# 547                                        Binance USD
# 548                                               BUSD
# 549                                        binance-usd
# 550                                               5086
# 551                           2019-09-20T00:00:00.000Z
# 552  [stablecoin, asset-backed-stablecoin, binance-...
# 553                                  20517253084.58926
# 554                                  20517253084.58926
# 555                                                  6
# 556                           2022-09-15T02:26:00.000Z
# 557                                            0.99914
# 558                                   9971169098.23416
# 559                                          -24.44170
# 560                                           -0.08409
# 561                                           -0.08645
# 562                                           -0.12018
# 563                                           -0.06862
# 564                                           -0.15318
# 565                                           -0.29739
# 566                                  20499546055.94763
# 567                                            2.07260
# 568                                  20499546055.95000
# 569                           2022-09-15T02:26:00.000Z
# 570                                         1839.00000
# 571                                                BNB
# 572                                                BNB
# 573                                                bnb
# 574                                           BUSD-BD1
# 575                         2022-09-15 02:28:08.062603
# 576                                                 52
# 577                                                XRP
# 578                                                XRP
# 579                                                xrp
# 580                                                814
# 581                           2013-08-04T00:00:00.000Z
# 582  [medium-of-exchange, enterprise-solutions, arr...
# 583                                 100000000000.00000
# 584                                  49826021773.00000
# 585                                  99989302361.00000
# 586                                                  7
# 587                           2022-09-15T02:26:00.000Z
# 588                                            0.33700
# 589                                   1207202475.12731
# 590                                          -16.55810
# 591                                           -0.87323
# 592                                            0.56496
# 593                                            1.49162
# 594                                           -9.44135
# 595                                           -3.79422
# 596                                            3.14098
# 597                                  16791329715.28789
# 598                                            1.69770
# 599                                  33699920478.87000
# 600                           2022-09-15T02:26:00.000Z
# 601                         2022-09-15 02:28:08.062603
# 602                                               2010
# 603                                            Cardano
# 604                                                ADA
# 605                                            cardano
# 606                                                569
# 607                           2017-10-01T00:00:00.000Z
# 608  [dpos, pos, platform, research, smart-contract...
# 609                                  45000000000.00000
# 610                                  34182044152.62900
# 611                                  34854947575.48000
# 612                                                  8
# 613                           2022-09-15T02:26:00.000Z
# 614                                            0.47319
# 615                                    732179300.43997
# 616                                          -26.89850
# 617                                           -0.80167
# 618                                            0.28683
# 619                                           -0.92560
# 620                                          -15.52760
# 621                                            4.59060
# 622                                           -3.35950
# 623                                  16174465973.04118
# 624                                            1.63450
# 625                                  21293371617.47000
# 626                           2022-09-15T02:26:00.000Z
# 627                         2022-09-15 02:28:08.062603
# 628                                               5426
# 629                                             Solana
# 630                                                SOL
# 631                                             solana
# 632                                                383
# 633                           2020-04-10T00:00:00.000Z
# 634  [pos, platform, solana-ecosystem, cms-holdings...
# 635                                    353848267.11550
# 636                                    511616946.14229
# 637                                                  9
# 638                           2022-09-15T02:26:00.000Z
# 639                                           33.51488
# 640                                    963134717.70034
# 641                                          -45.62860
# 642                                           -0.57820
# 643                                           -0.36760
# 644                                            3.11120
# 645                                          -23.26467
# 646                                          -15.13420
# 647                                            9.35802
# 648                                  11859180610.76805
# 649                                            1.19610
# 650                                  17146778242.81000
# 651                           2022-09-15T02:26:00.000Z
# 652                         2022-09-15 02:28:08.062603
# 653                                                 74
# 654                                           Dogecoin
# 655                                               DOGE
# 656                                           dogecoin
# 657                                                561
# 658                           2013-12-15T00:00:00.000Z
# 659  [mineable, pow, scrypt, medium-of-exchange, me...
# 660                                 132670764299.89409
# 661                                 132670764299.89409
# 662                                                 10
# 663                           2022-09-15T02:26:00.000Z
# 664                                            0.06035
# 665                                    359048609.66663
# 666                                          -21.94910
# 667                                           -0.97646
# 668                                           -0.00187
# 669                                           -1.00299
# 670                                          -23.57526
# 671                                           -5.70256
# 672                                            7.16875
# 673                                   8007009368.49166
# 674                                            0.80890
# 675                                   8007009368.49000
# 676                           2022-09-15T02:26:00.000Z
# 677                         2022-09-15 02:28:08.062603
# 678                                               6636
# 679                                           Polkadot
# 680                                                DOT
# 681                                       polkadot-new
# 682                                                410
# 683                           2020-08-19T00:00:00.000Z
# 684  [substrate, polkadot, binance-chain, polkadot-...
# 685                                   1132527619.33446
# 686                                   1232557368.87714
# 687                                                 11
# 688                                    904869778.00000
# 689                                   6365447627.83482
# 690                           2022-09-15T02:26:00.000Z
# 691                                            7.03466
# 692                                    321313192.91903
# 693                                          -32.78130
# 694                                           -0.88221
# 695                                           -2.04595
# 696                                           -2.40243
# 697                                          -20.13428
# 698                                           -1.07761
# 699                                           -3.28148
# 700                                   7966942231.05101
# 701                                            0.80510
# 702                                   8670617110.49000
# 703                           2022-09-15T02:26:00.000Z
# 704                         2022-09-15 02:28:08.062603
# 705                                               3890
# 706                                            Polygon
# 707                                              MATIC
# 708                                            polygon
# 709                                                484
# 710                           2019-04-28T00:00:00.000Z
# 711  [platform, enterprise-solutions, scaling, stat...
# 712                                  10000000000.00000
# 713                                   8734317475.28493
# 714                                  10000000000.00000
# 715                                                 12
# 716                           2022-09-15T02:26:00.000Z
# 717                                            0.84798
# 718                                    405637500.02957
# 719                                          -42.90480
# 720                                           -0.50219
# 721                                           -1.80370
# 722                                            0.57742
# 723                                          -11.47706
# 724                                           17.08748
# 725                                          116.70833
# 726                                   7406553454.09451
# 727                                            0.74700
# 728                                   8479830822.56000
# 729                           2022-09-15T02:26:00.000Z
# 730                         2022-09-15 02:28:08.062603
# 731                                               4943
# 732                                                Dai
# 733                                                DAI
# 734                               multi-collateral-dai
# 735                                               1336
# 736                           2019-11-22T00:00:00.000Z
# 737  [defi, stablecoin, asset-backed-stablecoin, et...
# 738                                   6839924162.06719
# 739                                   6839924162.06719
# 740                                                 13
# 741                           2022-09-15T02:26:00.000Z
# 742                                            0.99905
# 743                                    697775705.01893
# 744                                          -18.53650
# 745                                           -0.02721
# 746                                           -0.11066
# 747                                           -0.10025
# 748                                           -0.03827
# 749                                           -0.02871
# 750                                           -0.14976
# 751                                   6833452966.48641
# 752                                            0.69030
# 753                                   6833452966.49000
# 754                           2022-09-15T02:26:00.000Z
# 755                                         1027.00000
# 756                                           Ethereum
# 757                                                ETH
# 758                                           ethereum
# 759         0x6b175474e89094c44da98b954eedeac495271d0f
# 760                         2022-09-15 02:28:08.062603
# 761                                               5994
# 762                                          Shiba Inu
# 763                                               SHIB
# 764                                          shiba-inu
# 765                                                413
# 766                           2020-08-01T00:00:00.000Z
# 767      [memes, ethereum-ecosystem, doggone-doggerel]
# 768                              549063278876301.93750
# 769                              589735030408322.75000
# 770                                                 14
# 771                           2022-09-15T02:26:00.000Z
# 772                                            0.00001
# 773                                    311367632.30440
# 774                                          -31.94350
# 775                                           -0.53287
# 776                                           -1.88842
# 777                                           -1.64927
# 778                                          -22.74841
# 779                                           10.30389
# 780                                           47.27949
# 781                                   6620943027.27813
# 782                                            0.66910
# 783                                   7111388045.32000
# 784                           2022-09-15T02:26:00.000Z
# 785                                         1027.00000
# 786                                           Ethereum
# 787                                                ETH
# 788                                           ethereum
# 789         0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 790                         2022-09-15 02:28:08.062603
# 791                                               1958
# 792                                               TRON
# 793                                                TRX
# 794                                               tron
# 795                                                684
# 796                           2017-09-13T00:00:00.000Z
# 797                  [media, payments, tron-ecosystem]
# 798                                  92366671484.34125
# 799                                  92366665415.80617
# 800                                                 15
# 801                                  71659659264.00000
# 802                                   4373125246.45869
# 803                           2022-09-15T02:26:00.000Z
# 804                                            0.06103
# 805                                    349859652.37644
# 806                                          -13.99280
# 807                                           -0.43845
# 808                                           -0.29978
# 809                                            0.50735
# 810                                          -11.43989
# 811                                          -11.03340
# 812                                           -1.48665
# 813                                   5636797985.75951
# 814                                            0.56850
# 815                                   5636797615.42000
# 816                           2022-09-15T02:26:00.000Z
# 817                         2022-09-15 02:28:08.062603

# %%
import seaborn as sns
import matplotlib.pyplot as plt
